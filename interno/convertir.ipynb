# %%
import os
import re
import shutil
import time
import requests
from pathlib import Path
from datetime import datetime
from github import Github
from dotenv import load_dotenv
import zipfile
from urllib.parse import quote
import json

load_dotenv()

github = Github(os.getenv('GITHUB_TOKEN'))
print(os.getenv('GITHUB_TOKEN'))
# repo   = github.get_repo("AlejandroDiBattista/tup25-p4")

# %%
def listar_carpetas_tp(repo_full_name: str, carpeta_base: str = "TP", ref: str = "main") -> list[str]:
    """
    Devuelve la lista de nombres de carpetas hijas directas dentro de `carpeta_base` en el repositorio indicado.

    Parámetros:
    - repo_full_name: "owner/repo"
    - carpeta_base: ruta base (por defecto "tp")
    - ref: rama/etiqueta a consultar (por defecto "main")
    """
    token = os.getenv('GITHUB_TOKEN')
    print(f"Token: {token}")
    if not token:
        raise RuntimeError("Falta GITHUB_TOKEN en el entorno.")

    repo = github.get_repo(repo_full_name)
    try:
        contents = repo.get_contents(carpeta_base, ref=ref)
    except Exception as exc:  # p.ej. 404 si no existe la carpeta
        raise RuntimeError(f"No se pudo obtener '{carpeta_base}' en {repo_full_name}@{ref}: {exc}") from exc

    carpetas = [item.name for item in contents if item.type == "dir"]
    return sorted(carpetas)


def bajar_todas_las_carpetas_tp():
    salida = {}
    with open("carpetas_tp.txt", "w", encoding="utf-8") as f:
        for repo in ['TUP25-P3', 'TUP25-P4', 'TUP24-L3-C3', 'TUP24-L3-C4', 'TUP24-L3-C5', 'TUP24-L3-C9', 'TUP24-L4-C2', 'TUP24-L4-C5', 'TUP24-L4-C7', 'TUP24-L4-C9']:
            print(f"Procesando {repo}...")
            base = 'tp' if 'TUP25-P4' in repo else 'TP'
            carpetas = listar_carpetas_tp(f"AlejandroDiBattista/{repo}", carpeta_base=base)
            for carpeta in carpetas:
                legajo = carpeta.split('-')[0].strip()
                url = f"https://github.com/AlejandroDiBattista/{repo}/tree/main/{base}/{quote(carpeta)}"
                f.write(f"{repo}-{legajo}  {url}\n")
                salida[f"{repo}-{legajo}"] = carpeta
    return salida


carpetas_tp = bajar_todas_las_carpetas_tp()

alumnos_path = Path("./directorio-alumno/deploy/alumnos.json")
if alumnos_path.exists():
    alumnos = json.loads(alumnos_path.read_text(encoding="utf-8"))
    for alumno in alumnos.values():
        print(f"Alumno : {json.dumps(alumno)}")
        legajo = str(alumno.get("legajo", ""))
        for curso in alumno.get("cursos", []):
        #     "59022": {
        #     "legajo": "59022",
        #     "nombre": "Camaño Terán, Nicolás",
        #     "cursos": [
        #       {
        #         "año": 2024,
        #         "materia": "Laboratorio 3",
        #         "comision": "C3",
        #         "estado": "Promocionado",
        #         "codigo": "L3"
        #       }
        #     ],
        #     "foto": false
        #   },
        # repo_prefix    
            if curso.get("codigo") in ["P3", "P4"]:
                comision = ""
            else:
                comision = f"-{curso.get("comision")}"
            id = f"TUP{curso.get('año')-2000}-{curso.get('codigo')}-{legajo}"
            print(f"Buscando carpeta_tp para {id}...")
            if id in carpetas_tp:
                curso["carpeta_tp"] = carpetas_tp[id]
                print(f"Asignada carpeta_tp {carpetas_tp[id]} a {legajo} en {id}")
    print(alumnos)
    open("./directorio-alumno/deploy/alumnos_con_carpetas_tp.json", "w", encoding="utf-8").write(json.dumps(alumnos, indent=4, ensure_ascii=False))
else:
    print("No se encontró ./directorio-alumno/deploy/alumnos.json")
# Out:
# Procesando TUP25-P3...
# Token: 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
# Procesando TUP25-P4...
# Token: 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
# Procesando TUP24-L3-C3...
# Token: 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
# Procesando TUP24-L3-C4...
# Token: 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
# Procesando TUP24-L3-C5...
# Token: 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
# Procesando TUP24-L3-C9...
# Token: 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
# Procesando TUP24-L4-C2...
# Token: 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
# Procesando TUP24-L4-C5...
# Token: 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
# Procesando TUP24-L4-C7...
# Token: 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
# Procesando TUP24-L4-C9...
# Token: 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
# Alumno : {"legajo": "58931", "nombre": "Cabrera, Lucas Nahuel", "cursos": [{"a\u00f1o": 2024, "materia": "Laboratorio 3", "comision": "C3", "estado": "Promocionado", "codigo": "L3", "carpeta_tp": "58931 - Cabrera, Lucas Nahuel"}], "foto": false}
# Buscando carpeta_tp para TUP24-L3-58931...
# Alumno : {"legajo": "59022", "nombre": "Cama\u00f1o Ter\u00e1n, Nicol\u00e1s", "cursos": [{"a\u00f1o": 2024, "materia": "Laboratorio 3", "comision": "C3", "estado": "Promocionado", "codigo": "L3", "carpeta_tp": "59022 - Cama\u00f1o Ter\u00e1n, Nicol\u00e1s"}], "foto": false}
# Buscando carpeta_tp para TUP24-L3-59022...
# Alumno : {"legajo": "58889", "nombre": "Cap\u00f3, Mauricio Nicol\u00e1s", "cursos": [{"a\u00f1o": 2024, "materia": "Laboratorio 3", "comision": "C3", "estado": "Promocionado", "codigo": "L3", "carpeta_tp": "58889 - Cap\u00f3, Mauricio Nicol\u00e1s"}], "foto": false}
# Buscando carpeta_tp para TUP24-L3-58889...
# Alumno : {"legajo": "58770", "nombre": "Carabajal, Ariadna Micael", "cursos": [{"a\u00f1o": 2024, "materia": "Laboratorio 3", "comision": "C3", "estado": "Promocionado", "codigo": "L3", "carpeta_tp": "58770 - Carabajal, Ariadna Micael"}], "foto": false}
# Buscando carpeta_tp para TUP24-L3-58770...
# Alumno : {"legajo": "59046", "nombre": "Carrizo, Angel Nahuel", "cursos": [{"a\u00f1o": 2024, "materia": "Laboratorio 3", "comision": "C3", "estado": "Promocionado", "codigo": "L3", "carpeta_tp": "59046 - Carrizo, Angel Nahuel"}], "foto": false}
# Buscando carpeta_tp para TUP24-L3-59046...
# Alumno : {"legajo": "58925", "nombre": "Castillo, Martina", "cursos": [{"a\u00f1o": 2024, "materia": "Laboratorio 3", "comision": "C3", "estado": "Promocionado", "codigo": "L3", "carpeta_tp": "58925 - Castillo, Martina"}], "foto": false}
# Buscando carpeta_tp para TUP24-L3-58925...
# Alumno : {"legajo": "59016", "nombre": "Catania, Franco Mauricio", "cursos": [{"a\u00f1o": 2024, "materia": "Laboratorio 3", "comision": "C3", "estado": "Promocionado", "codigo": "L3", "carpeta_tp": "59016 - Catania, Franco Mauricio"}], "foto": false}
# Buscando carpeta_tp para TUP24-L3-59016...
# Alumno : {"legajo": "58813", "nombre": "Cervera, Diego Octavio", "cursos": [{"a\u00f1o": 2024, "materia": "Laboratorio 3", "comision": "C3", "estado": "Promocionado", "codigo": "L3", "carpeta_tp": "58813 - Cervera, Diego Octavio"}], "foto": false}
# Buscando carpeta_tp para TUP24-L3-58813...
# Alumno : {"legajo": "59379", "nombre": "Charkiewicz, Carolina Est", "cursos": [{"a\u00f1o": 2024, "materia": "Laboratorio 3", "comision": "C3", "estado": "Promocionado", "codigo": "L3", "carpeta_tp": "59379 - Charkiewicz, Carolina Est"}], "foto": false}
# Buscando carpeta_tp para TUP24-L3-59379...
# Alumno : {"legajo": "59347", "nombre": "Chein, Amir Elias", "cursos": [{"a\u00f1o": 2024, "materia": "Laboratorio 3", "comision": "C3", "estado": "Promocionado", "codigo": "L3", "carpeta_tp": "59347 - Chein, Amir Elias"}], "foto": false}
# Buscando carpeta_tp para TUP24-L3-59347...
# Alumno : {"legajo": "59315", "nombre": "Chein, Santiago", "cursos": [{"a\u00f1o": 2024, "materia": "Laboratorio 3", "comision": "C3", "estado": "Promocionado", "codigo": "L3", "carpeta_tp": "59315 - Chein, Santiago"}], "foto": false}
# Buscando carpeta_tp para TUP24-L3-59315...
# Alumno : {"legajo": "59083", "nombre": "Cuellar, Jos\u00e9 Omar", "cursos": [{"a\u00f1o": 2024, "materia": "Laboratorio 3", "comision": "C3", "estado": "Promocionado", "codigo": "L3", "carpeta_tp": "59083 - Cuellar, Jos\u00e9 Omar"}], "foto": false}
# Buscando carpeta_tp para TUP24-L3-59083...
# Alumno : {"legajo": "59063", "nombre": "Cuevas, Matias Sebasti\u00e1n", "cursos": [{"a\u00f1o": 2024, "materia": "Laboratorio 3", "comision": "C3", "estado": "Promocionado", "codigo": "L3", "carpeta_tp": "59063 - Cuevas, Matias Sebasti\u00e1n"}], "foto": false}
# Buscando carpeta_tp para TUP24-L3-59063...
# Alumno : {"legajo": "58888", "nombre": "Diaz G\u00f3mez, Andr\u00e9s Dario", "cursos": [{"a\u00f1o": 2024, "materia": "Laboratorio 3", "comision": "C3", "estado": "Promocionado", "codigo": "L3", "carpeta_tp": "58888 - Diaz G\u00f3mez, Andr\u00e9s Dario"}], "foto": false}
# Buscando carpeta_tp para TUP24-L3-58888...
# Alumno : {"legajo": "55249", "nombre": "Fernandez, Gonzalo Tomas", "cursos": [{"a\u00f1o": 2024, "materia": "Laboratorio 3", "comision": "C3", "estado": "Promocionado", "codigo": "L3", "carpeta_tp": "55249 - Fernandez, Gonzalo Tomas"}, {"a\u00f1o": 2024, "materia": "Laboratorio 4", "comision": "C5", "estado": "Pendiente", "codigo": "L4", "carpeta_tp": "55249 - Fernandez, Gonzalo Tomas"}], "foto": false}
# Buscando carpeta_tp para TUP24-L3-55249...
# Buscando carpeta_tp para TUP24-L4-55249...
# Alumno : {"legajo": "57565", "nombre": "Heredia, Fabricio Nicol\u00e1s", "cursos": [{"a\u00f1o": 2024, "materia": "Laboratorio 3", "comision": "C3", "estado": "Promocionado", "codigo": "L3", "carpeta_tp": "57565 - Heredia, Fabricio Nicol\u00e1s"}], "foto": false}
# Buscando carpeta_tp para TUP24-L3-57565...
# Alumno : {"legajo": "59184", "nombre": "Lucena, Matias Leandro", "cursos": [{"a\u00f1o": 2024, "materia": "Laboratorio 3", "comision": "C3", "estado": "Promocionado", "codigo": "L3", "carpeta_tp": "59184 - Lucena, Matias Leandro"}, {"a\u00f1o": 2024, "materia": "Laboratorio 4", "comision": "C5", "estado": "Pendiente", "codigo": "L4", "carpeta_tp": "59184 - Lucena, Mat\u00edas Leandro"}], "foto": false}
# Buscando carpeta_tp para TUP24-L3-59184...
# Buscando carpeta_tp para TUP24-L4-59184...
# Alumno : {"legajo": "59060", "nombre": "Martinez, Maira", "cursos": [{"a\u00f1o": 2024, "materia": "Laboratorio 3", "comision": "C3", "estado": "Promocionado", "codigo": "L3", "carpeta_tp": "59060 - Martinez, Maira"}], "foto": false}
# Buscando carpeta_tp para TUP24-L3-59060...
# Alumno : {"legajo": "59550", "nombre": "Osores Medina, Selena Pau", "cursos": [{"a\u00f1o": 2024, "materia": "Laboratorio 3", "comision": "C3", "estado": "Promocionado", "codigo": "L3", "carpeta_tp": "59550 - Osores Medina, Selena Pau"}], "foto": false}
# Buscando carpeta_tp para TUP24-L3-59550...
# Alumno : {"legajo": "59092", "nombre": "Perez, Luciano Damian", "cursos": [{"a\u00f1o": 2024, "materia": "Laboratorio 3", "comision": "C3", "estado": "Promocionado", "codigo": "L3", "carpeta_tp": "59092 - Perez, Luciano Damian"}], "foto": false}
# Buscando carpeta_tp para TUP24-L3-59092...
# Alumno : {"legajo": "58884", "nombre": "Salazar, Agustina Ximena", "cursos": [{"a\u00f1o": 2024, "materia": "Laboratorio 3", "comision": "C3", "estado": "Promocionado", "codigo": "L3", "carpeta_tp": "58884 - Salazar, Agustina Ximena"}], "foto": false}
# Buscando carpeta_tp para TUP24-L3-58884...
# Alumno : {"legajo": "58881", "nombre": "Sosa Juarez, Malena Lujan", "cursos": [{"a\u00f1o": 2024, "materia": "Laboratorio 3", "comision": "C3", "estado": "Promocionado", "codigo": "L3", "carpeta_tp": "58881 - Sosa Juarez, Malena Lujan"}], "foto": false}
# Buscando carpeta_tp para TUP24-L3-58881...
# Alumno : {"legajo": "58771", "nombre": "Calvo Maderuelo, Carlos M", "cursos": [{"a\u00f1o": 2024, "materia": "Laboratorio 3", "comision": "C3", "estado": "Regular", "codigo": "L3", "carpeta_tp": "58771 - Calvo Maderuelo, Carlos M"}], "foto": false}
# Buscando carpeta_tp para TUP24-L3-58771...
# Alumno : {"legajo": "55839", "nombre": "Castillo, Ignacio Agust\u00edn", "cursos": [{"a\u00f1o": 2024, "materia": "Laboratorio 3", "comision": "C3", "estado": "Regular", "codigo": "L3", "carpeta_tp": "55839 - Castillo, Ignacio Agust\u00edn"}], "foto": false}
# Buscando carpeta_tp para TUP24-L3-55839...
# Alumno : {"legajo": "59027", "nombre": "Chaves, Gonzalo Mart\u00edn", "cursos": [{"a\u00f1o": 2024, "materia": "Laboratorio 3", "comision": "C3", "estado": "Regular", "codigo": "L3", "carpeta_tp": "59027 - Chaves, Gonzalo Mart\u00edn"}], "foto": false}
# Buscando carpeta_tp para TUP24-L3-59027...
# Alumno : {"legajo": "58768", "nombre": "Cordoba, Ignacio Leandro", "cursos": [{"a\u00f1o": 2024, "materia": "Laboratorio 3", "comision": "C3", "estado": "Regular", "codigo": "L3", "carpeta_tp": "58768 - Cordoba, Ignacio Leandro"}], "foto": false}
# Buscando carpeta_tp para TUP24-L3-58768...
# Alumno : {"legajo": "58780", "nombre": "Coronel, Juan Carlos", "cursos": [{"a\u00f1o": 2024, "materia": "Laboratorio 3", "comision": "C3", "estado": "Regular", "codigo": "L3", "carpeta_tp": "58780 - Coronel, Juan Carlos"}], "foto": false}
# Buscando carpeta_tp para TUP24-L3-58780...
# Alumno : {"legajo": "58937", "nombre": "Coronel, Lucas Francisco", "cursos": [{"a\u00f1o": 2024, "materia": "Laboratorio 3", "comision": "C3", "estado": "Regular", "codigo": "L3", "carpeta_tp": "58937 - Coronel, Lucas Francisco"}], "foto": false}
# Buscando carpeta_tp para TUP24-L3-58937...
# Alumno : {"legajo": "59019", "nombre": "Corral Garcia, Mario Maxi", "cursos": [{"a\u00f1o": 2024, "materia": "Laboratorio 3", "comision": "C3", "estado": "Regular", "codigo": "L3", "carpeta_tp": "59019 - Corral Garcia, Mario Maxi"}], "foto": false}
# Buscando carpeta_tp para TUP24-L3-59019...
# Alumno : {"legajo": "58939", "nombre": "Cruz, Francisco Sebastian", "cursos": [{"a\u00f1o": 2024, "materia": "Laboratorio 3", "comision": "C3", "estado": "Regular", "codigo": "L3", "carpeta_tp": "58939 - Cruz, Francisco Sebastian"}], "foto": false}
# Buscando carpeta_tp para TUP24-L3-58939...
# Alumno : {"legajo": "59075", "nombre": "Delgado, Fabricio Tobias", "cursos": [{"a\u00f1o": 2024, "materia": "Laboratorio 3", "comision": "C3", "estado": "Regular", "codigo": "L3", "carpeta_tp": "59075 - Delgado, Fabricio Tobias"}], "foto": false}
# Buscando carpeta_tp para TUP24-L3-59075...
# Alumno : {"legajo": "59185", "nombre": "Diaz Ghiggia, Guillermo", "cursos": [{"a\u00f1o": 2024, "materia": "Laboratorio 3", "comision": "C3", "estado": "Regular", "codigo": "L3", "carpeta_tp": "59185 - Diaz Ghiggia, Guillermo"}], "foto": false}
# Buscando carpeta_tp para TUP24-L3-59185...
# Alumno : {"legajo": "58844", "nombre": "Diaz Gonzalez, Nahuel Ale", "cursos": [{"a\u00f1o": 2024, "materia": "Laboratorio 3", "comision": "C3", "estado": "Regular", "codigo": "L3", "carpeta_tp": "58844 - Diaz Gonzalez, Nahuel Ale"}], "foto": false}
# Buscando carpeta_tp para TUP24-L3-58844...
# Alumno : {"legajo": "58763", "nombre": "Donelli, Luciano", "cursos": [{"a\u00f1o": 2024, "materia": "Laboratorio 3", "comision": "C3", "estado": "Regular", "codigo": "L3", "carpeta_tp": "58763 - Donelli, Luciano"}], "foto": false}
# Buscando carpeta_tp para TUP24-L3-58763...
# Alumno : {"legajo": "59438", "nombre": "Martin, Leonardo Javier", "cursos": [{"a\u00f1o": 2024, "materia": "Laboratorio 3", "comision": "C3", "estado": "Regular", "codigo": "L3", "carpeta_tp": "59438 - Martin, Leonardo Javier"}], "foto": false}
# Buscando carpeta_tp para TUP24-L3-59438...
# Alumno : {"legajo": "55883", "nombre": "Pedraza, Leonardo Miguel", "cursos": [{"a\u00f1o": 2024, "materia": "Laboratorio 3", "comision": "C3", "estado": "Regular", "codigo": "L3", "carpeta_tp": "55883 - Pedraza, Leonardo Miguel"}], "foto": false}
# Buscando carpeta_tp para TUP24-L3-55883...
# Alumno : {"legajo": "58905", "nombre": "Sueldo, Leandro Antonio", "cursos": [{"a\u00f1o": 2024, "materia": "Laboratorio 3", "comision": "C3", "estado": "Regular", "codigo": "L3", "carpeta_tp": "58905 - Sueldo, Leandro Antonio"}], "foto": false}
# Buscando carpeta_tp para TUP24-L3-58905...
# Alumno : {"legajo": "50792", "nombre": "Tula Nelegatti, Agustin", "cursos": [{"a\u00f1o": 2024, "materia": "Laboratorio 3", "comision": "C3", "estado": "Regular", "codigo": "L3", "carpeta_tp": "50792 - Tula Nelegatti, Agustin"}], "foto": false}
# Buscando carpeta_tp para TUP24-L3-50792...
# Alumno : {"legajo": "57605", "nombre": "Auad, Ger\u00f3nimo", "cursos": [{"a\u00f1o": 2024, "materia": "Laboratorio 3", "comision": "C3", "estado": "Libre", "codigo": "L3", "carpeta_tp": "57605 - Auad, Ger\u00f3nimo"}], "foto": false}
# Buscando carpeta_tp para TUP24-L3-57605...
# Alumno : {"legajo": "59204", "nombre": "Aybar, Anibal Cesar Daniel", "cursos": [{"a\u00f1o": 2024, "materia": "Laboratorio 3", "comision": "C3", "estado": "Libre", "codigo": "L3", "carpeta_tp": "59204 - Aybar, Anibal Cesar Daniel"}], "foto": false}
# Buscando carpeta_tp para TUP24-L3-59204...
# Alumno : {"legajo": "59181", "nombre": "Castro, Maria Bel\u00e9n", "cursos": [{"a\u00f1o": 2024, "materia": "Laboratorio 3", "comision": "C3", "estado": "Libre", "codigo": "L3", "carpeta_tp": "59181 - Castro, Maria Bel\u00e9n"}], "foto": false}
# Buscando carpeta_tp para TUP24-L3-59181...
# Alumno : {"legajo": "57534", "nombre": "Delani, Luca", "cursos": [{"a\u00f1o": 2024, "materia": "Laboratorio 3", "comision": "C3", "estado": "Libre", "codigo": "L3", "carpeta_tp": "57534 - Delani, Luca"}], "foto": false}
# Buscando carpeta_tp para TUP24-L3-57534...
# Alumno : {"legajo": "58956", "nombre": "Diaz, Viviana Lorena", "cursos": [{"a\u00f1o": 2024, "materia": "Laboratorio 3", "comision": "C3", "estado": "Libre", "codigo": "L3", "carpeta_tp": "58956 - Diaz, Viviana Lorena"}], "foto": false}
# Buscando carpeta_tp para TUP24-L3-58956...
# Alumno : {"legajo": "58747", "nombre": "Diez Del Valle, Lucciano", "cursos": [{"a\u00f1o": 2024, "materia": "Laboratorio 3", "comision": "C3", "estado": "Libre", "codigo": "L3", "carpeta_tp": "58747 - Diez Del Valle, Lucciano"}], "foto": false}
# Buscando carpeta_tp para TUP24-L3-58747...
# Alumno : {"legajo": "55847", "nombre": "Elizondo Carreras, Lautaro", "cursos": [{"a\u00f1o": 2024, "materia": "Laboratorio 3", "comision": "C3", "estado": "Libre", "codigo": "L3", "carpeta_tp": "55847 - Elizondo Carreras, Lautaro"}], "foto": false}
# Buscando carpeta_tp para TUP24-L3-55847...
# Alumno : {"legajo": "59183", "nombre": "Fernandez, Ignacio", "cursos": [{"a\u00f1o": 2024, "materia": "Laboratorio 3", "comision": "C3", "estado": "Libre", "codigo": "L3", "carpeta_tp": "59183 - Fernandez, Ignacio"}], "foto": false}
# Buscando carpeta_tp para TUP24-L3-59183...
# Alumno : {"legajo": "59197", "nombre": "Peralta, Antonio Nicol\u00e1s", "cursos": [{"a\u00f1o": 2024, "materia": "Laboratorio 3", "comision": "C3", "estado": "Libre", "codigo": "L3", "carpeta_tp": "59197 - Peralta, Antonio Nicol\u00e1s"}], "foto": false}
# Buscando carpeta_tp para TUP24-L3-59197...
# Alumno : {"legajo": "59037", "nombre": "Rodriguez, Antonella Fern", "cursos": [{"a\u00f1o": 2024, "materia": "Laboratorio 3", "comision": "C3", "estado": "Libre", "codigo": "L3", "carpeta_tp": "59037 - Rodriguez, Antonella Fern"}], "foto": false}
# Buscando carpeta_tp para TUP24-L3-59037...
# Alumno : {"legajo": "59265", "nombre": "Cavanna, Victoria", "cursos": [{"a\u00f1o": 2024, "materia": "Laboratorio 3", "comision": "C4", "estado": "Promocionado", "codigo": "L3", "carpeta_tp": "59265 - Cavanna, Victoria"}], "foto": false}
# Buscando carpeta_tp para TUP24-L3-59265...
# Alumno : {"legajo": "55505", "nombre": "Chazarreta Robles, Mar\u00eda", "cursos": [{"a\u00f1o": 2024, "materia": "Laboratorio 3", "comision": "C4", "estado": "Promocionado", "codigo": "L3", "carpeta_tp": "55505 - Chazarreta Robles, Mar\u00eda"}], "foto": false}
# Buscando carpeta_tp para TUP24-L3-55505...
# Alumno : {"legajo": "50694", "nombre": "Ferrari, Stefano", "cursos": [{"a\u00f1o": 2024, "materia": "Laboratorio 3", "comision": "C4", "estado": "Promocionado", "codigo": "L3", "carpeta_tp": "50694 - Ferrari, Stefano"}], "foto": false}
# Buscando carpeta_tp para TUP24-L3-50694...
# Alumno : {"legajo": "58725", "nombre": "Garcia Bulacio, Micaela", "cursos": [{"a\u00f1o": 2024, "materia": "Laboratorio 3", "comision": "C4", "estado": "Promocionado", "codigo": "L3", "carpeta_tp": "58725 - Garcia Bulacio, Micaela"}], "foto": false}
# Buscando carpeta_tp para TUP24-L3-58725...
# Alumno : {"legajo": "59417", "nombre": "G\u00f3mez Iturre, Joaqu\u00edn", "cursos": [{"a\u00f1o": 2024, "materia": "Laboratorio 3", "comision": "C4", "estado": "Promocionado", "codigo": "L3", "carpeta_tp": "59417 - G\u00f3mez Iturre, Joaqu\u00edn"}], "foto": false}
# Buscando carpeta_tp para TUP24-L3-59417...
# Alumno : {"legajo": "59093", "nombre": "Ledesma, Facundo Osvaldo", "cursos": [{"a\u00f1o": 2024, "materia": "Laboratorio 3", "comision": "C4", "estado": "Promocionado", "codigo": "L3", "carpeta_tp": "59093 - Ledesma, Facundo Osvaldo"}], "foto": false}
# Buscando carpeta_tp para TUP24-L3-59093...
# Alumno : {"legajo": "59200", "nombre": "L\u00f3pez, Tiago Gabriel", "cursos": [{"a\u00f1o": 2024, "materia": "Laboratorio 3", "comision": "C4", "estado": "Promocionado", "codigo": "L3", "carpeta_tp": "59200 - L\u00f3pez, Tiago Gabriel"}], "foto": false}
# Buscando carpeta_tp para TUP24-L3-59200...
# Alumno : {"legajo": "55466", "nombre": "Medina, \u00c1lvaro Ignacio", "cursos": [{"a\u00f1o": 2024, "materia": "Laboratorio 3", "comision": "C4", "estado": "Promocionado", "codigo": "L3", "carpeta_tp": "55466 - Medina, \u00c1lvaro Ignacio"}], "foto": false}
# Buscando carpeta_tp para TUP24-L3-55466...
# Alumno : {"legajo": "55986", "nombre": "Paz, Octavio Emanuel", "cursos": [{"a\u00f1o": 2024, "materia": "Laboratorio 3", "comision": "C4", "estado": "Promocionado", "codigo": "L3", "carpeta_tp": "55986 - Paz, Octavio Emanuel"}], "foto": false}
# Buscando carpeta_tp para TUP24-L3-55986...
# Alumno : {"legajo": "50657", "nombre": "Ramirez, Giselle Evelyn", "cursos": [{"a\u00f1o": 2024, "materia": "Laboratorio 3", "comision": "C4", "estado": "Promocionado", "codigo": "L3", "carpeta_tp": "50657 - Ramirez, Giselle Evelyn"}], "foto": false}
# Buscando carpeta_tp para TUP24-L3-50657...
# Alumno : {"legajo": "59690", "nombre": "Rios, Yanina Gisele", "cursos": [{"a\u00f1o": 2024, "materia": "Laboratorio 3", "comision": "C4", "estado": "Promocionado", "codigo": "L3", "carpeta_tp": "59690 - Rios, Yanina Gisele"}], "foto": false}
# Buscando carpeta_tp para TUP24-L3-59690...
# Alumno : {"legajo": "58800", "nombre": "Valdez, Miguel Angel", "cursos": [{"a\u00f1o": 2024, "materia": "Laboratorio 3", "comision": "C4", "estado": "Promocionado", "codigo": "L3", "carpeta_tp": "58800 - Valdez, Miguel Angel"}], "foto": false}
# Buscando carpeta_tp para TUP24-L3-58800...
# Alumno : {"legajo": "59097", "nombre": "Martin Ibarra, Patricio", "cursos": [{"a\u00f1o": 2024, "materia": "Laboratorio 3", "comision": "C4", "estado": "Regular", "codigo": "L3", "carpeta_tp": "59097 - Martin Ibarra, Patricio"}], "foto": false}
# Buscando carpeta_tp para TUP24-L3-59097...
# Alumno : {"legajo": "58798", "nombre": "Salazar, Santiago", "cursos": [{"a\u00f1o": 2024, "materia": "Laboratorio 3", "comision": "C4", "estado": "Regular", "codigo": "L3", "carpeta_tp": "58798 - Salazar, Santiago"}], "foto": false}
# Buscando carpeta_tp para TUP24-L3-58798...
# Alumno : {"legajo": "59263", "nombre": "Acosta, Facundo", "cursos": [{"a\u00f1o": 2024, "materia": "Laboratorio 3", "comision": "C4", "estado": "Libre", "codigo": "L3", "carpeta_tp": "59263 - Acosta, Facundo"}], "foto": false}
# Buscando carpeta_tp para TUP24-L3-59263...
# Alumno : {"legajo": "50704", "nombre": "Juarez, Pablo Agust\u00edn", "cursos": [{"a\u00f1o": 2024, "materia": "Laboratorio 3", "comision": "C4", "estado": "Libre", "codigo": "L3", "carpeta_tp": "50704 - Juarez, Pablo Agust\u00edn"}], "foto": false}
# Buscando carpeta_tp para TUP24-L3-50704...
# Alumno : {"legajo": "55896", "nombre": "Lacroix, Cristian Josu\u00e9", "cursos": [{"a\u00f1o": 2024, "materia": "Laboratorio 3", "comision": "C4", "estado": "Libre", "codigo": "L3", "carpeta_tp": "55896 - Lacroix, Cristian Josu\u00e9"}], "foto": false}
# Buscando carpeta_tp para TUP24-L3-55896...
# Alumno : {"legajo": "50753", "nombre": "Villafa\u00f1e Assef, Oscar", "cursos": [{"a\u00f1o": 2024, "materia": "Laboratorio 3", "comision": "C4", "estado": "Libre", "codigo": "L3", "carpeta_tp": "50753 - Villafa\u00f1e Assef, Oscar"}], "foto": false}
# Buscando carpeta_tp para TUP24-L3-50753...
# Alumno : {"legajo": "55681", "nombre": "Bustos, Mauricio Benjamin", "cursos": [{"a\u00f1o": 2024, "materia": "Laboratorio 3", "comision": "C5", "estado": "Promocionado", "codigo": "L3", "carpeta_tp": "55681 - Bustos, Mauricio Benjamin"}], "foto": false}
# Buscando carpeta_tp para TUP24-L3-55681...
# Alumno : {"legajo": "55457", "nombre": "Carranza, Javier", "cursos": [{"a\u00f1o": 2024, "materia": "Laboratorio 3", "comision": "C5", "estado": "Promocionado", "codigo": "L3", "carpeta_tp": "55457 - Carranza, Javier"}], "foto": false}
# Buscando carpeta_tp para TUP24-L3-55457...
# Alumno : {"legajo": "58895", "nombre": "Flores Gonzalez, Tomas", "cursos": [{"a\u00f1o": 2024, "materia": "Laboratorio 3", "comision": "C5", "estado": "Promocionado", "codigo": "L3", "carpeta_tp": "58895 - Flores Gonzalez, Tomas"}, {"a\u00f1o": 2024, "materia": "Laboratorio 4", "comision": "C5", "estado": "Pendiente", "codigo": "L4", "carpeta_tp": "58895 - Flores Gonzalez, Tom\u00e1s Agust\u00edn"}], "foto": false}
# Buscando carpeta_tp para TUP24-L3-58895...
# Buscando carpeta_tp para TUP24-L4-58895...
# Alumno : {"legajo": "59154", "nombre": "Garcia, M\u00e1ximo", "cursos": [{"a\u00f1o": 2024, "materia": "Laboratorio 3", "comision": "C5", "estado": "Promocionado", "codigo": "L3", "carpeta_tp": "59154 - Garcia, M\u00e1ximo"}, {"a\u00f1o": 2024, "materia": "Laboratorio 4", "comision": "C5", "estado": "Promocionado", "codigo": "L4", "carpeta_tp": "59154 - Garc\u00eda, M\u00e1ximo"}], "foto": false}
# Buscando carpeta_tp para TUP24-L3-59154...
# Buscando carpeta_tp para TUP24-L4-59154...
# Alumno : {"legajo": "59076", "nombre": "Gomez Martinez, Matias", "cursos": [{"a\u00f1o": 2024, "materia": "Laboratorio 3", "comision": "C5", "estado": "Promocionado", "codigo": "L3", "carpeta_tp": "59076 - Gomez Martinez, Matias"}, {"a\u00f1o": 2024, "materia": "Laboratorio 4", "comision": "C5", "estado": "Promocionado", "codigo": "L4", "carpeta_tp": "59076 - G\u00f3mez Mart\u00ednez, Mat\u00edas Lionel"}], "foto": false}
# Buscando carpeta_tp para TUP24-L3-59076...
# Buscando carpeta_tp para TUP24-L4-59076...
# Alumno : {"legajo": "58894", "nombre": "Gonzalez Nacusse, Flavia", "cursos": [{"a\u00f1o": 2024, "materia": "Laboratorio 3", "comision": "C5", "estado": "Promocionado", "codigo": "L3", "carpeta_tp": "58894 - Gonzalez Nacusse, Flavia"}, {"a\u00f1o": 2024, "materia": "Laboratorio 4", "comision": "C5", "estado": "Promocionado", "codigo": "L4", "carpeta_tp": "58894 - Gonz\u00e1lez Nacusse, Flavia"}], "foto": false}
# Buscando carpeta_tp para TUP24-L3-58894...
# Buscando carpeta_tp para TUP24-L4-58894...
# Alumno : {"legajo": "58720", "nombre": "Gonzalez, Mart\u00edn Natanael", "cursos": [{"a\u00f1o": 2024, "materia": "Laboratorio 3", "comision": "C5", "estado": "Promocionado", "codigo": "L3", "carpeta_tp": "58720 - Gonzalez, Mart\u00edn Natanael"}, {"a\u00f1o": 2024, "materia": "Laboratorio 4", "comision": "C5", "estado": "Promocionado", "codigo": "L4", "carpeta_tp": "58720 - Gonzalez, Mart\u00edn Natanael"}], "foto": false}
# Buscando carpeta_tp para TUP24-L3-58720...
# Buscando carpeta_tp para TUP24-L4-58720...
# Alumno : {"legajo": "59068", "nombre": "Gonzalez, Silvina Mariela", "cursos": [{"a\u00f1o": 2024, "materia": "Laboratorio 3", "comision": "C5", "estado": "Promocionado", "codigo": "L3", "carpeta_tp": "59068 - Gonzalez, Silvina Mariela"}, {"a\u00f1o": 2024, "materia": "Laboratorio 4", "comision": "C5", "estado": "Pendiente", "codigo": "L4", "carpeta_tp": "59068 - Gonzalez, Silvina Mariela"}], "foto": false}
# Buscando carpeta_tp para TUP24-L3-59068...
# Buscando carpeta_tp para TUP24-L4-59068...
# Alumno : {"legajo": "58786", "nombre": "Gutierrez, Augusto Pedro", "cursos": [{"a\u00f1o": 2024, "materia": "Laboratorio 3", "comision": "C5", "estado": "Promocionado", "codigo": "L3", "carpeta_tp": "58786 - Gutierrez, Augusto Pedro"}], "foto": false}
# Buscando carpeta_tp para TUP24-L3-58786...
# Alumno : {"legajo": "58736", "nombre": "Juarez Hindi, Lucas David", "cursos": [{"a\u00f1o": 2024, "materia": "Laboratorio 3", "comision": "C5", "estado": "Promocionado", "codigo": "L3", "carpeta_tp": "58736 - Juarez Hindi, Lucas David"}, {"a\u00f1o": 2024, "materia": "Laboratorio 4", "comision": "C5", "estado": "Regular", "codigo": "L4", "carpeta_tp": "58736 - Juarez Hindi, Lucas David"}], "foto": false}
# Buscando carpeta_tp para TUP24-L3-58736...
# Buscando carpeta_tp para TUP24-L4-58736...
# Alumno : {"legajo": "58761", "nombre": "Juarez, Lautaro Andres", "cursos": [{"a\u00f1o": 2024, "materia": "Laboratorio 3", "comision": "C5", "estado": "Promocionado", "codigo": "L3", "carpeta_tp": "58761 - Juarez, Lautaro Andres"}, {"a\u00f1o": 2024, "materia": "Laboratorio 4", "comision": "C5", "estado": "Promocionado", "codigo": "L4", "carpeta_tp": "58761 - Juarez, Lautaro Andres En"}], "foto": false}
# Buscando carpeta_tp para TUP24-L3-58761...
# Buscando carpeta_tp para TUP24-L4-58761...
# Alumno : {"legajo": "58758", "nombre": "Juarez, Milagro Macarena", "cursos": [{"a\u00f1o": 2024, "materia": "Laboratorio 3", "comision": "C5", "estado": "Promocionado", "codigo": "L3", "carpeta_tp": "58758 - Juarez, Milagro Macarena"}, {"a\u00f1o": 2024, "materia": "Laboratorio 4", "comision": "C5", "estado": "Promocionado", "codigo": "L4", "carpeta_tp": "58758 - Juarez, Milagro Macarena"}], "foto": false}
# Buscando carpeta_tp para TUP24-L3-58758...
# Buscando carpeta_tp para TUP24-L4-58758...
# Alumno : {"legajo": "58721", "nombre": "Juncos, Gonzalo Sebastian", "cursos": [{"a\u00f1o": 2024, "materia": "Laboratorio 3", "comision": "C5", "estado": "Promocionado", "codigo": "L3", "carpeta_tp": "58721 - Juncos, Gonzalo Sebastian"}, {"a\u00f1o": 2024, "materia": "Laboratorio 4", "comision": "C5", "estado": "Promocionado", "codigo": "L4", "carpeta_tp": "58721 - Juncos, Gonzalo Sebastian"}], "foto": false}
# Buscando carpeta_tp para TUP24-L3-58721...
# Buscando carpeta_tp para TUP24-L4-58721...
# Alumno : {"legajo": "58756", "nombre": "Lazarte, Agustina Milagro", "cursos": [{"a\u00f1o": 2024, "materia": "Laboratorio 3", "comision": "C5", "estado": "Promocionado", "codigo": "L3", "carpeta_tp": "58756 - Lazarte, Agustina Milagro"}, {"a\u00f1o": 2024, "materia": "Laboratorio 4", "comision": "C5", "estado": "Promocionado", "codigo": "L4", "carpeta_tp": "58756 - Lazarte, Agustina Milagro"}], "foto": false}
# Buscando carpeta_tp para TUP24-L3-58756...
# Buscando carpeta_tp para TUP24-L4-58756...
# Alumno : {"legajo": "58727", "nombre": "Lazarte, Lucas", "cursos": [{"a\u00f1o": 2024, "materia": "Laboratorio 3", "comision": "C5", "estado": "Promocionado", "codigo": "L3", "carpeta_tp": "58727 - Lazarte, Lucas"}, {"a\u00f1o": 2024, "materia": "Laboratorio 4", "comision": "C5", "estado": "Promocionado", "codigo": "L4", "carpeta_tp": "58727 - Lazarte, Lucas"}], "foto": false}
# Buscando carpeta_tp para TUP24-L3-58727...
# Buscando carpeta_tp para TUP24-L4-58727...
# Alumno : {"legajo": "59099", "nombre": "Moyano Berrondo, Tahiel L", "cursos": [{"a\u00f1o": 2024, "materia": "Laboratorio 3", "comision": "C5", "estado": "Promocionado", "codigo": "L3", "carpeta_tp": "59099 - Moyano Berrondo, Tahiel L"}, {"a\u00f1o": 2024, "materia": "Laboratorio 4", "comision": "C5", "estado": "Regular", "codigo": "L4", "carpeta_tp": "59099 - Moyano Berrondo, Tahiel"}], "foto": false}
# Buscando carpeta_tp para TUP24-L3-59099...
# Buscando carpeta_tp para TUP24-L4-59099...
# Alumno : {"legajo": "58805", "nombre": "Prieto, Matias Hernan", "cursos": [{"a\u00f1o": 2024, "materia": "Laboratorio 3", "comision": "C5", "estado": "Promocionado", "codigo": "L3", "carpeta_tp": "58805 - Prieto, Matias Hernan"}, {"a\u00f1o": 2024, "materia": "Laboratorio 4", "comision": "C5", "estado": "Promocionado", "codigo": "L4", "carpeta_tp": "58805 - Prieto, Mat\u00edas Hernan"}], "foto": false}
# Buscando carpeta_tp para TUP24-L3-58805...
# Buscando carpeta_tp para TUP24-L4-58805...
# Alumno : {"legajo": "59054", "nombre": "Rahman Rintoul, Ramiro", "cursos": [{"a\u00f1o": 2024, "materia": "Laboratorio 3", "comision": "C5", "estado": "Promocionado", "codigo": "L3", "carpeta_tp": "59054 - Rahman Rintoul, Ramiro"}, {"a\u00f1o": 2024, "materia": "Laboratorio 4", "comision": "C5", "estado": "Promocionado", "codigo": "L4", "carpeta_tp": "59054 - Rahman Rintoul, Ramiro"}], "foto": false}
# Buscando carpeta_tp para TUP24-L3-59054...
# Buscando carpeta_tp para TUP24-L4-59054...
# Alumno : {"legajo": "58766", "nombre": "Reinoso, Lisandro Gabriel", "cursos": [{"a\u00f1o": 2024, "materia": "Laboratorio 3", "comision": "C5", "estado": "Promocionado", "codigo": "L3", "carpeta_tp": "58766 - Reinoso, Lisandro Gabriel"}, {"a\u00f1o": 2024, "materia": "Laboratorio 4", "comision": "C5", "estado": "Promocionado", "codigo": "L4", "carpeta_tp": "58766 - Reinoso, Lisandro Gabriel"}], "foto": false}
# Buscando carpeta_tp para TUP24-L3-58766...
# Buscando carpeta_tp para TUP24-L4-58766...
# Alumno : {"legajo": "58753", "nombre": "Rivadeneira, Lautaro", "cursos": [{"a\u00f1o": 2024, "materia": "Laboratorio 3", "comision": "C5", "estado": "Promocionado", "codigo": "L3", "carpeta_tp": "58753 - Rivadeneira, Lautaro"}, {"a\u00f1o": 2024, "materia": "Laboratorio 4", "comision": "C5", "estado": "Promocionado", "codigo": "L4", "carpeta_tp": "58753 - Rivadeneira, Lautaro"}], "foto": false}
# Buscando carpeta_tp para TUP24-L3-58753...
# Buscando carpeta_tp para TUP24-L4-58753...
# Alumno : {"legajo": "58806", "nombre": "Rojas, Carlos Augusto", "cursos": [{"a\u00f1o": 2024, "materia": "Laboratorio 3", "comision": "C5", "estado": "Promocionado", "codigo": "L3", "carpeta_tp": "58806 - Rojas, Carlos Augusto"}, {"a\u00f1o": 2024, "materia": "Laboratorio 4", "comision": "C5", "estado": "Promocionado", "codigo": "L4", "carpeta_tp": "58806 - Rojas, Carlos Augusto"}], "foto": false}
# Buscando carpeta_tp para TUP24-L3-58806...
# Buscando carpeta_tp para TUP24-L4-58806...
# Alumno : {"legajo": "58845", "nombre": "Terrera, Augusto Dante", "cursos": [{"a\u00f1o": 2024, "materia": "Laboratorio 3", "comision": "C5", "estado": "Promocionado", "codigo": "L3", "carpeta_tp": "58845 - Terrera, Augusto Dante"}, {"a\u00f1o": 2024, "materia": "Laboratorio 4", "comision": "C5", "estado": "Promocionado", "codigo": "L4", "carpeta_tp": "58845 - Terrera, Augusto Dante"}], "foto": false}
# Buscando carpeta_tp para TUP24-L3-58845...
# Buscando carpeta_tp para TUP24-L4-58845...
# Alumno : {"legajo": "59188", "nombre": "Vaca, Andres Emanuel", "cursos": [{"a\u00f1o": 2024, "materia": "Laboratorio 3", "comision": "C5", "estado": "Promocionado", "codigo": "L3", "carpeta_tp": "59188 - Vaca, Andres Emanuel"}, {"a\u00f1o": 2024, "materia": "Laboratorio 4", "comision": "C5", "estado": "Promocionado", "codigo": "L4", "carpeta_tp": "59188 - Vaca, Andr\u00e9s Emanuel"}], "foto": false}
# Buscando carpeta_tp para TUP24-L3-59188...
# Buscando carpeta_tp para TUP24-L4-59188...
# Alumno : {"legajo": "58773", "nombre": "Elli Salazar, Ger\u00f3nimo", "cursos": [{"a\u00f1o": 2024, "materia": "Laboratorio 3", "comision": "C5", "estado": "Regular", "codigo": "L3", "carpeta_tp": "58773 - Elli Salazar, Ger\u00f3nimo"}, {"a\u00f1o": 2024, "materia": "Laboratorio 4", "comision": "C5", "estado": "Regular", "codigo": "L4", "carpeta_tp": "58773 - Ell\u00ed Salazar, Ger\u00f3nimo"}], "foto": false}
# Buscando carpeta_tp para TUP24-L3-58773...
# Buscando carpeta_tp para TUP24-L4-58773...
# Alumno : {"legajo": "55578", "nombre": "Fernandez Dumit, Patricio", "cursos": [{"a\u00f1o": 2024, "materia": "Laboratorio 3", "comision": "C5", "estado": "Regular", "codigo": "L3", "carpeta_tp": "55578 - Fernandez Dumit, Patricio"}, {"a\u00f1o": 2024, "materia": "Laboratorio 4", "comision": "C5", "estado": "Pendiente", "codigo": "L4", "carpeta_tp": "55578 - Fern\u00e1ndez Dumit, Patricio"}], "foto": false}
# Buscando carpeta_tp para TUP24-L3-55578...
# Buscando carpeta_tp para TUP24-L4-55578...
# Alumno : {"legajo": "58735", "nombre": "Fernandez Gomez, Manuel", "cursos": [{"a\u00f1o": 2024, "materia": "Laboratorio 3", "comision": "C5", "estado": "Regular", "codigo": "L3", "carpeta_tp": "58735 - Fernandez Gomez, Manuel"}, {"a\u00f1o": 2024, "materia": "Laboratorio 4", "comision": "C5", "estado": "Promocionado", "codigo": "L4", "carpeta_tp": "58735 - Fernandez Gomez, Manuel A"}], "foto": false}
# Buscando carpeta_tp para TUP24-L3-58735...
# Buscando carpeta_tp para TUP24-L4-58735...
# Alumno : {"legajo": "58723", "nombre": "Figueroa, Santiago Isaac", "cursos": [{"a\u00f1o": 2024, "materia": "Laboratorio 3", "comision": "C5", "estado": "Regular", "codigo": "L3", "carpeta_tp": "58723 - Figueroa, Santiago Isaac"}, {"a\u00f1o": 2024, "materia": "Laboratorio 4", "comision": "C5", "estado": "Promocionado", "codigo": "L4", "carpeta_tp": "58723 - Figueroa, Santiago Isaac"}], "foto": false}
# Buscando carpeta_tp para TUP24-L3-58723...
# Buscando carpeta_tp para TUP24-L4-58723...
# Alumno : {"legajo": "58781", "nombre": "Frias Armengol, Facundo", "cursos": [{"a\u00f1o": 2024, "materia": "Laboratorio 3", "comision": "C5", "estado": "Regular", "codigo": "L3", "carpeta_tp": "58781 - Frias Armengol, Facundo"}], "foto": false}
# Buscando carpeta_tp para TUP24-L3-58781...
# Alumno : {"legajo": "58734", "nombre": "Galvan, Victor Mateo", "cursos": [{"a\u00f1o": 2024, "materia": "Laboratorio 3", "comision": "C5", "estado": "Regular", "codigo": "L3", "carpeta_tp": "58734 - Galvan, Victor Mateo"}, {"a\u00f1o": 2024, "materia": "Laboratorio 4", "comision": "C5", "estado": "Promocionado", "codigo": "L4", "carpeta_tp": "58734 - Galv\u00e1n, V\u00edctor Mateo"}], "foto": false}
# Buscando carpeta_tp para TUP24-L3-58734...
# Buscando carpeta_tp para TUP24-L4-58734...
# Alumno : {"legajo": "58740", "nombre": "Garcia, Sergio Mart\u00edn", "cursos": [{"a\u00f1o": 2024, "materia": "Laboratorio 3", "comision": "C5", "estado": "Regular", "codigo": "L3", "carpeta_tp": "58740 - Garcia, Sergio Mart\u00edn"}, {"a\u00f1o": 2024, "materia": "Laboratorio 4", "comision": "C5", "estado": "Promocionado", "codigo": "L4", "carpeta_tp": "58740 - Garc\u00eda, Sergio Mart\u00edn"}], "foto": false}
# Buscando carpeta_tp para TUP24-L3-58740...
# Buscando carpeta_tp para TUP24-L4-58740...
# Alumno : {"legajo": "59135", "nombre": "Gomez, Facundo Matias", "cursos": [{"a\u00f1o": 2024, "materia": "Laboratorio 3", "comision": "C5", "estado": "Regular", "codigo": "L3", "carpeta_tp": "59135 - Gomez, Facundo Matias"}, {"a\u00f1o": 2024, "materia": "Laboratorio 4", "comision": "C5", "estado": "Libre", "codigo": "L4", "carpeta_tp": "59135 - G\u00f3mez, Facundo Mat\u00edas"}], "foto": false}
# Buscando carpeta_tp para TUP24-L3-59135...
# Buscando carpeta_tp para TUP24-L4-59135...
# Alumno : {"legajo": "59488", "nombre": "Gonzalez, Mariano Emanuel", "cursos": [{"a\u00f1o": 2024, "materia": "Laboratorio 3", "comision": "C5", "estado": "Regular", "codigo": "L3", "carpeta_tp": "59488 - Gonzalez, Mariano Emanuel"}, {"a\u00f1o": 2024, "materia": "Laboratorio 4", "comision": "C5", "estado": "Promocionado", "codigo": "L4", "carpeta_tp": "59488 - Gonz\u00e1lez, Mariano Emanuel"}], "foto": false}
# Buscando carpeta_tp para TUP24-L3-59488...
# Buscando carpeta_tp para TUP24-L4-59488...
# Alumno : {"legajo": "58880", "nombre": "Gutierrez, Cecilia Ana Lu", "cursos": [{"a\u00f1o": 2024, "materia": "Laboratorio 3", "comision": "C5", "estado": "Regular", "codigo": "L3", "carpeta_tp": "58880 - Gutierrez, Cecilia Ana Lu"}], "foto": false}
# Buscando carpeta_tp para TUP24-L3-58880...
# Alumno : {"legajo": "58687", "nombre": "Jadur, Sofia Nahir", "cursos": [{"a\u00f1o": 2024, "materia": "Laboratorio 3", "comision": "C5", "estado": "Regular", "codigo": "L3", "carpeta_tp": "58687 - Jadur, Sofia Nahir"}, {"a\u00f1o": 2024, "materia": "Laboratorio 4", "comision": "C5", "estado": "Pendiente", "codigo": "L4", "carpeta_tp": "58687 - Jadur, Sof\u00eda Nahir"}], "foto": false}
# Buscando carpeta_tp para TUP24-L3-58687...
# Buscando carpeta_tp para TUP24-L4-58687...
# Alumno : {"legajo": "59070", "nombre": "Ladina, Maia Agostina", "cursos": [{"a\u00f1o": 2024, "materia": "Laboratorio 3", "comision": "C5", "estado": "Regular", "codigo": "L3", "carpeta_tp": "59070 - Ladina, Maia Agostina"}, {"a\u00f1o": 2024, "materia": "Laboratorio 4", "comision": "C5", "estado": "Promocionado", "codigo": "L4", "carpeta_tp": "59070 - Ladina, Maia Agostina"}], "foto": false}
# Buscando carpeta_tp para TUP24-L3-59070...
# Buscando carpeta_tp para TUP24-L4-59070...
# Alumno : {"legajo": "58737", "nombre": "Lasagna, Manuel", "cursos": [{"a\u00f1o": 2024, "materia": "Laboratorio 3", "comision": "C5", "estado": "Regular", "codigo": "L3", "carpeta_tp": "58737 - Lasagna, Manuel"}, {"a\u00f1o": 2024, "materia": "Laboratorio 4", "comision": "C5", "estado": "Libre", "codigo": "L4", "carpeta_tp": "58737 - Lasagna, Manuel"}], "foto": false}
# Buscando carpeta_tp para TUP24-L3-58737...
# Buscando carpeta_tp para TUP24-L4-58737...
# Alumno : {"legajo": "59152", "nombre": "Lopez Chipoloni, Agustin", "cursos": [{"a\u00f1o": 2024, "materia": "Laboratorio 3", "comision": "C5", "estado": "Regular", "codigo": "L3", "carpeta_tp": "59152 - Lopez Chipoloni, Agustin"}, {"a\u00f1o": 2024, "materia": "Laboratorio 4", "comision": "C5", "estado": "Promocionado", "codigo": "L4", "carpeta_tp": "59152 - Lopez Chipoloni, Agustin"}], "foto": false}
# Buscando carpeta_tp para TUP24-L3-59152...
# Buscando carpeta_tp para TUP24-L4-59152...
# Alumno : {"legajo": "58724", "nombre": "Lopez Garcia, Marcos Juli", "cursos": [{"a\u00f1o": 2024, "materia": "Laboratorio 3", "comision": "C5", "estado": "Regular", "codigo": "L3", "carpeta_tp": "58724 - Lopez Garcia, Marcos Juli"}, {"a\u00f1o": 2024, "materia": "Laboratorio 4", "comision": "C5", "estado": "Regular", "codigo": "L4", "carpeta_tp": "58724 - Lopez Garcia, Marcos Julio"}], "foto": false}
# Buscando carpeta_tp para TUP24-L3-58724...
# Buscando carpeta_tp para TUP24-L4-58724...
# Alumno : {"legajo": "58726", "nombre": "Lopez, Fausto Agustin", "cursos": [{"a\u00f1o": 2024, "materia": "Laboratorio 3", "comision": "C5", "estado": "Regular", "codigo": "L3", "carpeta_tp": "58726 - Lopez, Fausto Agustin"}, {"a\u00f1o": 2024, "materia": "Laboratorio 4", "comision": "C5", "estado": "Promocionado", "codigo": "L4", "carpeta_tp": "58726 - Lopez, Fausto Agustin"}], "foto": false}
# Buscando carpeta_tp para TUP24-L3-58726...
# Buscando carpeta_tp para TUP24-L4-58726...
# Alumno : {"legajo": "58729", "nombre": "Lovey, Mathias Exequiel", "cursos": [{"a\u00f1o": 2024, "materia": "Laboratorio 3", "comision": "C5", "estado": "Regular", "codigo": "L3", "carpeta_tp": "58729 - Lovey, Mathias Exequiel"}, {"a\u00f1o": 2024, "materia": "Laboratorio 4", "comision": "C5", "estado": "Pendiente", "codigo": "L4", "carpeta_tp": "58729 - Lovey, Mathias Exequiel"}], "foto": false}
# Buscando carpeta_tp para TUP24-L3-58729...
# Buscando carpeta_tp para TUP24-L4-58729...
# Alumno : {"legajo": "59071", "nombre": "Medina, Daiana Micaela", "cursos": [{"a\u00f1o": 2024, "materia": "Laboratorio 3", "comision": "C5", "estado": "Regular", "codigo": "L3", "carpeta_tp": "59071 - Medina, Daiana Micaela"}, {"a\u00f1o": 2024, "materia": "Laboratorio 4", "comision": "C5", "estado": "Promocionado", "codigo": "L4", "carpeta_tp": "59071 - Medina, Daiana Micaela"}], "foto": false}
# Buscando carpeta_tp para TUP24-L3-59071...
# Buscando carpeta_tp para TUP24-L4-59071...
# Alumno : {"legajo": "59001", "nombre": "Peralta, Axel Rubens", "cursos": [{"a\u00f1o": 2024, "materia": "Laboratorio 3", "comision": "C5", "estado": "Regular", "codigo": "L3", "carpeta_tp": "59001 - Peralta, Axel Rubens"}], "foto": false}
# Buscando carpeta_tp para TUP24-L3-59001...
# Alumno : {"legajo": "58951", "nombre": "Robles, Ezequiel", "cursos": [{"a\u00f1o": 2024, "materia": "Laboratorio 3", "comision": "C5", "estado": "Regular", "codigo": "L3", "carpeta_tp": "58951 - Robles, Ezequiel"}, {"a\u00f1o": 2024, "materia": "Laboratorio 4", "comision": "C5", "estado": "Pendiente", "codigo": "L4", "carpeta_tp": "58951 - Robles, Ezequiel"}], "foto": false}
# Buscando carpeta_tp para TUP24-L3-58951...
# Buscando carpeta_tp para TUP24-L4-58951...
# Alumno : {"legajo": "58686", "nombre": "Rodriguez, Gustavo", "cursos": [{"a\u00f1o": 2024, "materia": "Laboratorio 3", "comision": "C5", "estado": "Regular", "codigo": "L3", "carpeta_tp": "58686 - Rodriguez, Gustavo"}, {"a\u00f1o": 2024, "materia": "Laboratorio 4", "comision": "C5", "estado": "Promocionado", "codigo": "L4", "carpeta_tp": "58686 - Rodriguez, Gustavo"}], "foto": false}
# Buscando carpeta_tp para TUP24-L3-58686...
# Buscando carpeta_tp para TUP24-L4-58686...
# Alumno : {"legajo": "58692", "nombre": "Rosello Salas, Maia Josef", "cursos": [{"a\u00f1o": 2024, "materia": "Laboratorio 3", "comision": "C5", "estado": "Regular", "codigo": "L3", "carpeta_tp": "58692 - Rosello Salas, Maia Josef"}, {"a\u00f1o": 2024, "materia": "Laboratorio 4", "comision": "C5", "estado": "Regular", "codigo": "L4", "carpeta_tp": "58692 - Rosselo Salas, Maia Josefina"}], "foto": false}
# Buscando carpeta_tp para TUP24-L3-58692...
# Buscando carpeta_tp para TUP24-L4-58692...
# Alumno : {"legajo": "58873", "nombre": "Salazar, Enzo Gabriel", "cursos": [{"a\u00f1o": 2024, "materia": "Laboratorio 3", "comision": "C5", "estado": "Regular", "codigo": "L3", "carpeta_tp": "58873 - Salazar, Enzo Gabriel"}, {"a\u00f1o": 2024, "materia": "Laboratorio 4", "comision": "C5", "estado": "Regular", "codigo": "L4", "carpeta_tp": "58873 - Salazar, Enzo Gabriel"}], "foto": false}
# Buscando carpeta_tp para TUP24-L3-58873...
# Buscando carpeta_tp para TUP24-L4-58873...
# Alumno : {"legajo": "55870", "nombre": "Stemberger, Emiliano", "cursos": [{"a\u00f1o": 2024, "materia": "Laboratorio 3", "comision": "C5", "estado": "Regular", "codigo": "L3", "carpeta_tp": "55870 - Stemberger, Emiliano"}, {"a\u00f1o": 2024, "materia": "Laboratorio 4", "comision": "C5", "estado": "Pendiente", "codigo": "L4", "carpeta_tp": "55870 - Stemberger, Emiliano"}], "foto": false}
# Buscando carpeta_tp para TUP24-L3-55870...
# Buscando carpeta_tp para TUP24-L4-55870...
# Alumno : {"legajo": "59052", "nombre": "Teseira, Lucas Benjamin", "cursos": [{"a\u00f1o": 2024, "materia": "Laboratorio 3", "comision": "C5", "estado": "Regular", "codigo": "L3", "carpeta_tp": "59052 - Teseira, Lucas Benjamin"}, {"a\u00f1o": 2024, "materia": "Laboratorio 4", "comision": "C5", "estado": "Libre", "codigo": "L4", "carpeta_tp": "59052 - Teseira, Lucas Benjamin"}], "foto": false}
# Buscando carpeta_tp para TUP24-L3-59052...
# Buscando carpeta_tp para TUP24-L4-59052...
# Alumno : {"legajo": "57543", "nombre": "Touceda, Federico", "cursos": [{"a\u00f1o": 2024, "materia": "Laboratorio 3", "comision": "C5", "estado": "Regular", "codigo": "L3", "carpeta_tp": "57543 - Touceda, Federico"}, {"a\u00f1o": 2024, "materia": "Laboratorio 4", "comision": "C5", "estado": "Promocionado", "codigo": "L4", "carpeta_tp": "57543 - Touceda, Federico"}], "foto": false}
# Buscando carpeta_tp para TUP24-L3-57543...
# Buscando carpeta_tp para TUP24-L4-57543...
# Alumno : {"legajo": "59064", "nombre": "Urbani, Juan Pablo", "cursos": [{"a\u00f1o": 2024, "materia": "Laboratorio 3", "comision": "C5", "estado": "Regular", "codigo": "L3", "carpeta_tp": "59064 - Urbani, Juan Pablo"}, {"a\u00f1o": 2024, "materia": "Laboratorio 4", "comision": "C5", "estado": "Promocionado", "codigo": "L4", "carpeta_tp": "59064 - Urbani, Juan Pablo"}], "foto": false}
# Buscando carpeta_tp para TUP24-L3-59064...
# Buscando carpeta_tp para TUP24-L4-59064...
# Alumno : {"legajo": "58899", "nombre": "Villagra, Juan Gabriel", "cursos": [{"a\u00f1o": 2024, "materia": "Laboratorio 3", "comision": "C5", "estado": "Regular", "codigo": "L3", "carpeta_tp": "58899 - Villagra, Juan Gabriel"}, {"a\u00f1o": 2024, "materia": "Laboratorio 4", "comision": "C5", "estado": "Promocionado", "codigo": "L4", "carpeta_tp": "58899 - Villagra, Juan Gabriel"}], "foto": false}
# Buscando carpeta_tp para TUP24-L3-58899...
# Buscando carpeta_tp para TUP24-L4-58899...
# Alumno : {"legajo": "59909", "nombre": "Wierna, Bel\u00e9n", "cursos": [{"a\u00f1o": 2024, "materia": "Laboratorio 3", "comision": "C5", "estado": "Regular", "codigo": "L3", "carpeta_tp": "59909 - Wierna, Bel\u00e9n"}, {"a\u00f1o": 2024, "materia": "Laboratorio 4", "comision": "C5", "estado": "Libre", "codigo": "L4", "carpeta_tp": "59909 - Wierna, Mar\u00eda Bel\u00e9n"}], "foto": false}
# Buscando carpeta_tp para TUP24-L3-59909...
# Buscando carpeta_tp para TUP24-L4-59909...
# Alumno : {"legajo": "55751", "nombre": "Jer\u00e9z, Francisco David", "cursos": [{"a\u00f1o": 2024, "materia": "Laboratorio 3", "comision": "C5", "estado": "Libre", "codigo": "L3", "carpeta_tp": "55751 - Jer\u00e9z, Francisco David"}, {"a\u00f1o": 2024, "materia": "Laboratorio 4", "comision": "C2", "estado": "Pendiente", "codigo": "L4", "carpeta_tp": "55751 - J\u00e9rez, Francisco David"}], "foto": false}
# Buscando carpeta_tp para TUP24-L3-55751...
# Buscando carpeta_tp para TUP24-L4-55751...
# Alumno : {"legajo": "58842", "nombre": "Fernandez Licciardi, Mauricio", "cursos": [{"a\u00f1o": 2024, "materia": "Laboratorio 3", "comision": "C9", "estado": "Promocionado", "codigo": "L3", "carpeta_tp": "58842 - Fernandez Licciardi, Mauricio"}, {"a\u00f1o": 2024, "materia": "Laboratorio 4", "comision": "C9", "estado": "Promocionado", "codigo": "L4", "carpeta_tp": "58842 - Fern\u00e1ndez Licciardi, Mauricio"}], "foto": false}
# Buscando carpeta_tp para TUP24-L3-58842...
# Buscando carpeta_tp para TUP24-L4-58842...
# Alumno : {"legajo": "59053", "nombre": "Guzm\u00e1n, Esteban Leonel", "cursos": [{"a\u00f1o": 2024, "materia": "Laboratorio 3", "comision": "C9", "estado": "Promocionado", "codigo": "L3", "carpeta_tp": "59053 - Guzm\u00e1n, Esteban Leonel"}], "foto": false}
# Buscando carpeta_tp para TUP24-L3-59053...
# Alumno : {"legajo": "59310", "nombre": "Paz Berrondo, Nahuel Agus", "cursos": [{"a\u00f1o": 2024, "materia": "Laboratorio 3", "comision": "C9", "estado": "Promocionado", "codigo": "L3", "carpeta_tp": "59310 - Paz Berrondo, Nahuel Agus"}, {"a\u00f1o": 2024, "materia": "Laboratorio 4", "comision": "C9", "estado": "Promocionado", "codigo": "L4", "carpeta_tp": "59310 - Paz Berrondo, Nahuel Agust\u00edn"}], "foto": false}
# Buscando carpeta_tp para TUP24-L3-59310...
# Buscando carpeta_tp para TUP24-L4-59310...
# Alumno : {"legajo": "59313", "nombre": "Pisentte, Juan Pablo", "cursos": [{"a\u00f1o": 2024, "materia": "Laboratorio 3", "comision": "C9", "estado": "Promocionado", "codigo": "L3", "carpeta_tp": "59313 - Pisentte, Juan Pablo"}, {"a\u00f1o": 2024, "materia": "Laboratorio 4", "comision": "C9", "estado": "Promocionado", "codigo": "L4", "carpeta_tp": "59313 - Pisentte, Juan Pablo"}], "foto": false}
# Buscando carpeta_tp para TUP24-L3-59313...
# Buscando carpeta_tp para TUP24-L4-59313...
# Alumno : {"legajo": "58879", "nombre": "Ruiu, Andr\u00e9s", "cursos": [{"a\u00f1o": 2024, "materia": "Laboratorio 3", "comision": "C9", "estado": "Promocionado", "codigo": "L3", "carpeta_tp": "58879 - Ruiu, Andr\u00e9s"}, {"a\u00f1o": 2024, "materia": "Laboratorio 4", "comision": "C9", "estado": "Promocionado", "codigo": "L4", "carpeta_tp": "58879 - Ruiu, Andres"}], "foto": false}
# Buscando carpeta_tp para TUP24-L3-58879...
# Buscando carpeta_tp para TUP24-L4-58879...
# ...
# Buscando carpeta_tp para TUP25-P3-61858...
# Asignada carpeta_tp 61858 - Perez, Facundo Agustin a 61858 en TUP25-P3-61858
# Alumno : {"legajo": "62612", "nombre": "Campos, Julieta Antonella", "cursos": [{"a\u00f1o": 2025, "materia": "Programaci\u00f3n 3", "comision": "C5", "estado": "Libre", "codigo": "P3"}], "telefono": "(381) 605-0864", "github": "@julicamposs", "foto": false}
# Buscando carpeta_tp para TUP25-P3-62612...
# Asignada carpeta_tp 62612 - Campos, Julieta Antonella a 62612 en TUP25-P3-62612
# Alumno : {"legajo": "61131", "nombre": "Agostino Colombres, Juan Manuel", "cursos": [{"a\u00f1o": 2025, "materia": "Programaci\u00f3n 4", "comision": "C1", "estado": "Promocionado", "codigo": "P4"}], "telefono": "(381) 684-8399", "github": "@JuanmaAgostino", "foto": true}
# Buscando carpeta_tp para TUP25-P4-61131...
# Asignada carpeta_tp 61131 - Agostino Colombres, Juan Manuel a 61131 en TUP25-P4-61131
# Alumno : {"legajo": "61682", "nombre": "Benitez, Gabriel", "cursos": [{"a\u00f1o": 2025, "materia": "Programaci\u00f3n 4", "comision": "C1", "estado": "Promocionado", "codigo": "P4"}], "telefono": "(381) 403\u20119540", "foto": true}
# Buscando carpeta_tp para TUP25-P4-61682...
# Alumno : {"legajo": "61565", "nombre": "Carrizo, Mauro", "cursos": [{"a\u00f1o": 2025, "materia": "Programaci\u00f3n 4", "comision": "C1", "estado": "Promocionado", "codigo": "P4"}], "telefono": "(381) 610-8745", "github": "@DarkoDarkShadow", "foto": true}
# Buscando carpeta_tp para TUP25-P4-61565...
# Asignada carpeta_tp 61565 - Carrizo, Mauro a 61565 en TUP25-P4-61565
# Alumno : {"legajo": "61236", "nombre": "Drachenberg, Franco Eduardo", "cursos": [{"a\u00f1o": 2025, "materia": "Programaci\u00f3n 4", "comision": "C1", "estado": "Promocionado", "codigo": "P4"}], "telefono": "(381) 670-8708", "github": "@FDrach", "foto": true}
# Buscando carpeta_tp para TUP25-P4-61236...
# Asignada carpeta_tp 61236 - Drachenberg, Franco Eduardo a 61236 en TUP25-P4-61236
# Alumno : {"legajo": "61198", "nombre": "Ferreyra Appas, Santiago Nicol\u00e1s", "cursos": [{"a\u00f1o": 2025, "materia": "Programaci\u00f3n 4", "comision": "C1", "estado": "Promocionado", "codigo": "P4"}], "telefono": "(381) 648-4455", "github": "@Ercutt", "foto": true}
# Buscando carpeta_tp para TUP25-P4-61198...
# Asignada carpeta_tp 61198 - Ferreyra Appas, Santiago Nicolás a 61198 en TUP25-P4-61198
# Alumno : {"legajo": "61167", "nombre": "Giacobbe, Franco", "cursos": [{"a\u00f1o": 2025, "materia": "Programaci\u00f3n 4", "comision": "C1", "estado": "Promocionado", "codigo": "P4"}], "telefono": "(381) 588-0371", "github": "@frandg47", "foto": true}
# Buscando carpeta_tp para TUP25-P4-61167...
# Asignada carpeta_tp 61167 - Giacobbe, Franco a 61167 en TUP25-P4-61167
# Alumno : {"legajo": "61073", "nombre": "Gonz\u00e1lez Chavez, Rodrigo", "cursos": [{"a\u00f1o": 2025, "materia": "Programaci\u00f3n 4", "comision": "C1", "estado": "Promocionado", "codigo": "P4"}], "telefono": "(381) 624-3000", "github": "@rodrigogc21", "foto": true}
# Buscando carpeta_tp para TUP25-P4-61073...
# Asignada carpeta_tp 61073 - González Chavez, Rodrigo a 61073 en TUP25-P4-61073
# Alumno : {"legajo": "61120", "nombre": "Guerrero, Ana Sof\u00eda", "cursos": [{"a\u00f1o": 2025, "materia": "Programaci\u00f3n 4", "comision": "C1", "estado": "Promocionado", "codigo": "P4"}], "telefono": "(381) 418-1564", "github": "@AnaSofi03", "foto": false}
# Buscando carpeta_tp para TUP25-P4-61120...
# Asignada carpeta_tp 61120 - Guerrero, Ana Sofía a 61120 en TUP25-P4-61120
# Alumno : {"legajo": "54911", "nombre": "Jatib, Rodrigo Gabriel", "cursos": [{"a\u00f1o": 2025, "materia": "Programaci\u00f3n 4", "comision": "C1", "estado": "Promocionado", "codigo": "P4"}], "telefono": "(381) 655-3096", "github": "@RodrigoJatib", "foto": true}
# Buscando carpeta_tp para TUP25-P4-54911...
# Asignada carpeta_tp 54911 - Jatib, Rodrigo Gabriel a 54911 en TUP25-P4-54911
# Alumno : {"legajo": "61035", "nombre": "Ledesma, Paulo Marcelo", "cursos": [{"a\u00f1o": 2025, "materia": "Programaci\u00f3n 4", "comision": "C1", "estado": "Promocionado", "codigo": "P4"}], "telefono": "(381) 664-8356", "github": "@pauloled", "foto": true}
# Buscando carpeta_tp para TUP25-P4-61035...
# Asignada carpeta_tp 61035 - Ledesma, Paulo Marcelo a 61035 en TUP25-P4-61035
# Alumno : {"legajo": "61115", "nombre": "Ledesma, Santiago Esteban", "cursos": [{"a\u00f1o": 2025, "materia": "Programaci\u00f3n 4", "comision": "C1", "estado": "Promocionado", "codigo": "P4"}], "telefono": "(381) 346-3696", "github": "@santled", "foto": true}
# Buscando carpeta_tp para TUP25-P4-61115...
# Asignada carpeta_tp 61115 - Ledesma, Santiago Esteban a 61115 en TUP25-P4-61115
# Alumno : {"legajo": "61335", "nombre": "Le\u00f3n, Lucas Ismael", "cursos": [{"a\u00f1o": 2025, "materia": "Programaci\u00f3n 4", "comision": "C1", "estado": "Promocionado", "codigo": "P4"}], "telefono": "(381) 609-7898", "github": "@LuquitasLeon", "foto": true}
# Buscando carpeta_tp para TUP25-P4-61335...
# Asignada carpeta_tp 61335 - León, Lucas Ismael a 61335 en TUP25-P4-61335
# Alumno : {"legajo": "61911", "nombre": "Llanos, Luciano", "cursos": [{"a\u00f1o": 2025, "materia": "Programaci\u00f3n 4", "comision": "C1", "estado": "Promocionado", "codigo": "P4"}], "telefono": "(381) 325-9224", "github": "@LucianoLlanos", "foto": true}
# Buscando carpeta_tp para TUP25-P4-61911...
# Asignada carpeta_tp 61911 - Llanos, Luciano a 61911 en TUP25-P4-61911
# Alumno : {"legajo": "61993", "nombre": "Medina, Juan Ignacio", "cursos": [{"a\u00f1o": 2025, "materia": "Programaci\u00f3n 4", "comision": "C1", "estado": "Promocionado", "codigo": "P4"}], "telefono": "(381) 517-1937", "github": "@Soulmain1", "foto": true}
# Buscando carpeta_tp para TUP25-P4-61993...
# Asignada carpeta_tp 61993 - Medina, Juan Ignacio a 61993 en TUP25-P4-61993
# Alumno : {"legajo": "61338", "nombre": "Morales, Juan Daniel", "cursos": [{"a\u00f1o": 2025, "materia": "Programaci\u00f3n 4", "comision": "C1", "estado": "Promocionado", "codigo": "P4"}], "telefono": "(381) 665-5296", "github": "@JuanMo17", "foto": true}
# Buscando carpeta_tp para TUP25-P4-61338...
# Asignada carpeta_tp 61338 - Morales, Juan Daniel a 61338 en TUP25-P4-61338
# Alumno : {"legajo": "61046", "nombre": "Ponce, Luz Micaela", "cursos": [{"a\u00f1o": 2025, "materia": "Programaci\u00f3n 4", "comision": "C1", "estado": "Promocionado", "codigo": "P4"}], "telefono": "(381) 664-7165", "github": "@Mica8p", "foto": true}
# Buscando carpeta_tp para TUP25-P4-61046...
# Asignada carpeta_tp 61046 - Ponce, Luz Micaela a 61046 en TUP25-P4-61046
# Alumno : {"legajo": "61033", "nombre": "Quiroga, Jos\u00e9 Mar\u00eda", "cursos": [{"a\u00f1o": 2025, "materia": "Programaci\u00f3n 4", "comision": "C1", "estado": "Promocionado", "codigo": "P4"}], "telefono": "(11) 2399-7675", "github": "@jose-qui", "foto": true}
# Buscando carpeta_tp para TUP25-P4-61033...
# Asignada carpeta_tp 61033 - Quiroga, José María a 61033 en TUP25-P4-61033
# Alumno : {"legajo": "62175", "nombre": "Quiroga, Marcela Noem\u00ed", "cursos": [{"a\u00f1o": 2025, "materia": "Programaci\u00f3n 4", "comision": "C1", "estado": "Promocionado", "codigo": "P4"}], "telefono": "(381) 593-8430", "github": "@Marce-Quiroga", "foto": true}
# Buscando carpeta_tp para TUP25-P4-62175...
# Asignada carpeta_tp 62175 - Quiroga, Marcela Noemí a 62175 en TUP25-P4-62175
# Alumno : {"legajo": "61084", "nombre": "Ram\u00edrez, Leonardo", "cursos": [{"a\u00f1o": 2025, "materia": "Programaci\u00f3n 4", "comision": "C1", "estado": "Promocionado", "codigo": "P4"}], "telefono": "(381) 348-9132", "github": "@Leoramirez777", "foto": true}
# Buscando carpeta_tp para TUP25-P4-61084...
# Asignada carpeta_tp 61084 - Ramírez, Leonardo a 61084 en TUP25-P4-61084
# Alumno : {"legajo": "61315", "nombre": "Robles, Thiago", "cursos": [{"a\u00f1o": 2025, "materia": "Programaci\u00f3n 4", "comision": "C1", "estado": "Promocionado", "codigo": "P4"}], "telefono": "(381) 344-7120", "github": "@T1T0Dev", "foto": true}
# Buscando carpeta_tp para TUP25-P4-61315...
# Asignada carpeta_tp 61315 - Robles, Thiago a 61315 en TUP25-P4-61315
# Alumno : {"legajo": "61468", "nombre": "Samaniego, Esteban Maximiliano", "cursos": [{"a\u00f1o": 2025, "materia": "Programaci\u00f3n 4", "comision": "C1", "estado": "Promocionado", "codigo": "P4"}], "telefono": "(381) 679-6586", "github": "@MaxiSama12", "foto": true}
# Buscando carpeta_tp para TUP25-P4-61468...
# Asignada carpeta_tp 61468 - Samaniego, Esteban Maximiliano a 61468 en TUP25-P4-61468
# Alumno : {"legajo": "61240", "nombre": "Timo, H\u00e9ctor Gabriel", "cursos": [{"a\u00f1o": 2025, "materia": "Programaci\u00f3n 4", "comision": "C1", "estado": "Promocionado", "codigo": "P4"}], "telefono": "(381) 343-0992", "github": "@GabrielTimo006", "foto": true}
# Buscando carpeta_tp para TUP25-P4-61240...
# Asignada carpeta_tp 61240 - Timo, Héctor Gabriel a 61240 en TUP25-P4-61240
# Alumno : {"legajo": "61725", "nombre": "Villagra, Jorge Sebasti\u00e1n", "cursos": [{"a\u00f1o": 2025, "materia": "Programaci\u00f3n 4", "comision": "C1", "estado": "Promocionado", "codigo": "P4"}], "telefono": "(381) 594-1635", "github": "@JorgeVillagraa", "foto": true}
# Buscando carpeta_tp para TUP25-P4-61725...
# Asignada carpeta_tp 61725 - Villagra, Jorge Sebastián a 61725 en TUP25-P4-61725
# Alumno : {"legajo": "61551", "nombre": "D\u00edaz Valdez, Ignacio", "cursos": [{"a\u00f1o": 2025, "materia": "Programaci\u00f3n 4", "comision": "C1", "estado": "Regular", "codigo": "P4"}], "telefono": "(381) 695-8566", "github": "@IgnacioDiazV", "foto": true}
# Buscando carpeta_tp para TUP25-P4-61551...
# Asignada carpeta_tp 61551 - Díaz Valdez, Ignacio a 61551 en TUP25-P4-61551
# Alumno : {"legajo": "61472", "nombre": "D\u00edaz, Julieta Camila", "cursos": [{"a\u00f1o": 2025, "materia": "Programaci\u00f3n 4", "comision": "C1", "estado": "Regular", "codigo": "P4"}], "telefono": "(381) 652-9981", "github": "@juliidiiaz04", "foto": false}
# Buscando carpeta_tp para TUP25-P4-61472...
# Asignada carpeta_tp 61472 - Díaz, Julieta Camila a 61472 en TUP25-P4-61472
# Alumno : {"legajo": "62318", "nombre": "Quiroga Castro, Lisandro", "cursos": [{"a\u00f1o": 2025, "materia": "Programaci\u00f3n 4", "comision": "C1", "estado": "Regular", "codigo": "P4"}], "telefono": "(381) 390-9133", "github": "@Lisandro-18", "foto": true}
# Buscando carpeta_tp para TUP25-P4-62318...
# Asignada carpeta_tp 62318 - Quiroga Castro, Lisandro a 62318 en TUP25-P4-62318
# Alumno : {"legajo": "61337", "nombre": "D\u00edaz, Christian Gabriel", "cursos": [{"a\u00f1o": 2025, "materia": "Programaci\u00f3n 4", "comision": "C1", "estado": "Libre", "codigo": "P4"}], "telefono": "(381) 571-4797", "github": "", "foto": false}
# Buscando carpeta_tp para TUP25-P4-61337...
# Asignada carpeta_tp 61337 - Díaz, Christian Gabriel a 61337 en TUP25-P4-61337
# Alumno : {"legajo": "61805", "nombre": "Jerez, Tom\u00e1s", "cursos": [{"a\u00f1o": 2025, "materia": "Programaci\u00f3n 4", "comision": "C1", "estado": "Libre", "codigo": "P4"}], "telefono": "(381) 338-0186", "github": "@ElTommmy", "foto": false}
# Buscando carpeta_tp para TUP25-P4-61805...
# Asignada carpeta_tp 61805 - Jerez, Tomás a 61805 en TUP25-P4-61805
# Alumno : {"legajo": "61719", "nombre": "Amoedo, Pablo Isa\u00edas", "cursos": [{"a\u00f1o": 2025, "materia": "Programaci\u00f3n 4", "comision": "C3", "estado": "Promocionado", "codigo": "P4"}], "telefono": "(381) 463-6126", "github": "@Kryfter", "foto": true}
# Buscando carpeta_tp para TUP25-P4-61719...
# Asignada carpeta_tp 61719 - Amoedo, Pablo Isaías a 61719 en TUP25-P4-61719
# Alumno : {"legajo": "61150", "nombre": "Molina Navarro, Juan Mart\u00edn", "cursos": [{"a\u00f1o": 2025, "materia": "Programaci\u00f3n 4", "comision": "C3", "estado": "Promocionado", "codigo": "P4"}], "telefono": "(381) 644-3413", "github": "@JuanMolinaNavarro", "foto": true}
# Buscando carpeta_tp para TUP25-P4-61150...
# Asignada carpeta_tp 61150 - Molina Navarro, Juan Martín a 61150 en TUP25-P4-61150
# {'58931': {'legajo': '58931', 'nombre': 'Cabrera, Lucas Nahuel', 'cursos': [{'año': 2024, 'materia': 'Laboratorio 3', 'comision': 'C3', 'estado': 'Promocionado', 'codigo': 'L3', 'carpeta_tp': '58931 - Cabrera, Lucas Nahuel'}], 'foto': False}, '59022': {'legajo': '59022', 'nombre': 'Camaño Terán, Nicolás', 'cursos': [{'año': 2024, 'materia': 'Laboratorio 3', 'comision': 'C3', 'estado': 'Promocionado', 'codigo': 'L3', 'carpeta_tp': '59022 - Camaño Terán, Nicolás'}], 'foto': False}, '58889': {'legajo': '58889', 'nombre': 'Capó, Mauricio Nicolás', 'cursos': [{'año': 2024, 'materia': 'Laboratorio 3', 'comision': 'C3', 'estado': 'Promocionado', 'codigo': 'L3', 'carpeta_tp': '58889 - Capó, Mauricio Nicolás'}], 'foto': False}, '58770': {'legajo': '58770', 'nombre': 'Carabajal, Ariadna Micael', 'cursos': [{'año': 2024, 'materia': 'Laboratorio 3', 'comision': 'C3', 'estado': 'Promocionado', 'codigo': 'L3', 'carpeta_tp': '58770 - Carabajal, Ariadna Micael'}], 'foto': False}, '59046': {'legajo': '59046', 'nombre': 'Carrizo, Angel Nahuel', 'cursos': [{'año': 2024, 'materia': 'Laboratorio 3', 'comision': 'C3', 'estado': 'Promocionado', 'codigo': 'L3', 'carpeta_tp': '59046 - Carrizo, Angel Nahuel'}], 'foto': False}, '58925': {'legajo': '58925', 'nombre': 'Castillo, Martina', 'cursos': [{'año': 2024, 'materia': 'Laboratorio 3', 'comision': 'C3', 'estado': 'Promocionado', 'codigo': 'L3', 'carpeta_tp': '58925 - Castillo, Martina'}], 'foto': False}, '59016': {'legajo': '59016', 'nombre': 'Catania, Franco Mauricio', 'cursos': [{'año': 2024, 'materia': 'Laboratorio 3', 'comision': 'C3', 'estado': 'Promocionado', 'codigo': 'L3', 'carpeta_tp': '59016 - Catania, Franco Mauricio'}], 'foto': False}, '58813': {'legajo': '58813', 'nombre': 'Cervera, Diego Octavio', 'cursos': [{'año': 2024, 'materia': 'Laboratorio 3', 'comision': 'C3', 'estado': 'Promocionado', 'codigo': 'L3', 'carpeta_tp': '58813 - Cervera, Diego Octavio'}], 'foto': False}, '59379': {'legajo': '59379', 'nombre': 'Charkiewicz, Carolina Est', 'cursos': [{'año': 2024, 'materia': 'Laboratorio 3', 'comision': 'C3', 'estado': 'Promocionado', 'codigo': 'L3', 'carpeta_tp': '59379 - Charkiewicz, Carolina Est'}], 'foto': False}, '59347': {'legajo': '59347', 'nombre': 'Chein, Amir Elias', 'cursos': [{'año': 2024, 'materia': 'Laboratorio 3', 'comision': 'C3', 'estado': 'Promocionado', 'codigo': 'L3', 'carpeta_tp': '59347 - Chein, Amir Elias'}], 'foto': False}, '59315': {'legajo': '59315', 'nombre': 'Chein, Santiago', 'cursos': [{'año': 2024, 'materia': 'Laboratorio 3', 'comision': 'C3', 'estado': 'Promocionado', 'codigo': 'L3', 'carpeta_tp': '59315 - Chein, Santiago'}], 'foto': False}, '59083': {'legajo': '59083', 'nombre': 'Cuellar, José Omar', 'cursos': [{'año': 2024, 'materia': 'Laboratorio 3', 'comision': 'C3', 'estado': 'Promocionado', 'codigo': 'L3', 'carpeta_tp': '59083 - Cuellar, José Omar'}], 'foto': False}, '59063': {'legajo': '59063', 'nombre': 'Cuevas, Matias Sebastián', 'cursos': [{'año': 2024, 'materia': 'Laboratorio 3', 'comision': 'C3', 'estado': 'Promocionado', 'codigo': 'L3', 'carpeta_tp': '59063 - Cuevas, Matias Sebastián'}], 'foto': False}, '58888': {'legajo': '58888', 'nombre': 'Diaz Gómez, Andrés Dario', 'cursos': [{'año': 2024, 'materia': 'Laboratorio 3', 'comision': 'C3', 'estado': 'Promocionado', 'codigo': 'L3', 'carpeta_tp': '58888 - Diaz Gómez, Andrés Dario'}], 'foto': False}, '55249': {'legajo': '55249', 'nombre': 'Fernandez, Gonzalo Tomas', 'cursos': [{'año': 2024, 'materia': 'Laboratorio 3', 'comision': 'C3', 'estado': 'Promocionado', 'codigo': 'L3', 'carpeta_tp': '55249 - Fernandez, Gonzalo Tomas'}, {'año': 2024, 'materia': 'Laboratorio 4', 'comision': 'C5', 'estado': 'Pendiente', 'codigo': 'L4', 'carpeta_tp': '55249 - Fernandez, Gonzalo Tomas'}], 'foto': False}, '57565': {'legajo': '57565', 'nombre': 'Heredia, Fabricio Nicolás', 'cursos': [{'año': 2024, 'materia': 'Laboratorio 3', 'comision': 'C3', 'estado': 'Promocionado', 'codigo': 'L3', 'carpeta_tp': '57565 - Hered ...

# %%
def leer(origen: str = "./alumnos.md") -> list:
    """
    Lee un archivo markdown con datos de alumnos y devuelve una lista de diccionarios.
    """

    print(f"> Leyendo {origen}... 😅")
    salida, comision = [], ""
    with open(origen, "r", encoding='utf-8') as archivo:
        for linea in archivo:
            if not linea.strip():
                continue

            # Normalizar espacios iniciales para aceptar tanto '- ...' como ' - ...'
            sline = linea.lstrip()
            if sline.startswith("## "):
                comision = int(sline.strip("# \n")[-1])

            if sline.startswith("- "):
                sline = sline.replace("@","")
                partes = re.split(r"\s{2,}", sline.strip("- \n@"))
                while len(partes) < 6:
                    partes.append("")
                # print(f">>>{partes[0]}|||{len(partes)}<<<")
                legajo, nombre, telefono, practicos, nota, github = partes
                n = nota.split(' ')
                # print(f">>{legajo}||{nota}||{nota}||{n}<<")
                p1 = int(n[0], 10)
                p2 = int(n[2], 10) if len(n) == 4 else 0
                valores = dict(zip(['legajo', 'nombre', 'telefono', 'github', 'comision', 'nota_1', 'nota_2'], [legajo, nombre, telefono, github, comision, p1, p2]))

                for i, p in enumerate(practicos, 1):
                    match p:
                        case "0": p = "🔴"
                        case "1": p = "🟢"
                    valores[f"TP{i}"] = p
                valores["aviso"] = "⚠️" if valores["github"] == "" else ""
                salida.append(valores)
    print(f"| {len(salida)} alumnos leídos.")
    return sorted(salida, key=lambda x: [x['comision'], x['legajo']])


def escribir(alumnos, destino="alumnos2.md", orden_practicos=False, promocionables=False):
    """
    Escribe un archivo markdown con datos de alumnos a partir de una lista de diccionarios.
    """
    
    def orden_estado(alumno):
        # practicos = [p for p in alumno.keys() if p.startswith("TP")]
        nonlocal practicos
        n = sum([1 for p in practicos if alumno[p] == "🔴"])
        if alumno[practicos[-1]] == "🔴": n += 50
        if n > 3: n += 100
        return n
    
    def normalizar_presentados(practicos):
        salida = []
        for p in practicos:
            match p:
                case "0" | "⚪" : p = "🔴"
                case "1" : p = "🟢"
            salida.append(p)
        return "".join(salida)
    
    def seccion(resultado):
        match resultado:
            case "Promocionado": return "## Aprobación directa"
            case "Pendiente":    return "## Promoción en suspenso"
            case "Regular":      return "## Regulares"
            case "Libre":        return "## Libre"
            case "Oyente":       return "## Oyentes"
        return None
            
    practicos = [f"TP{i}" for i in range(1, 9)]
    print(f"> Detectando prácticos... {practicos}")
    practicos = [p for p in practicos if p in alumnos[0]]

    print(f"> Practicos detectados: {', '.join(practicos)}")
    
    print(f"> Escribiendo {destino}...")

    if orden_practicos:
        print("> Ordenando por prácticos presentados...")
        alumnos = sorted(alumnos, key=lambda alumno: [alumno['comision'], orden_estado(alumno), alumno["legajo"]])
    else:
        alumnos = sorted(alumnos, key=lambda alumno: [alumno['comision'], alumno["nombre"]])
    with open(destino, "w", encoding='utf-8') as archivo:
        archivo.write("# Programación 4 | TUP 25\n")
        for comision in sorted(set(alumno['comision'] for alumno in alumnos)):
            archivo.write(f"\n## Comisión {comision}\n")
            for resultado in ["Promocionado", "Pendiente", "Regular", "Libre"]:
                copiar = list(filter(lambda a: a['resultado'] == resultado and a['comision'] == comision, alumnos))
    # ==>
                cantidad = len(copiar)
                print(f"1. > Procesando comisión {comision} - {resultado}... Hay {cantidad} alumnos")
                if cantidad == 0:
                    print(f"2. > No hay alumnos para {comision} - {resultado}, se omite sección.")
                    continue
                print(f"3. > Escribiendo sección {comision} - {resultado} con {cantidad} alumnos...")
                archivo.write(f"\n{seccion(resultado)} ({cantidad})\n")
                archivo.write("```text\n")
                for alumno in copiar:
                    print(f"4. > Escribiendo alumno {alumno['legajo']} - {alumno['nombre']}...")
                    presentado = map(str, [alumno[p] for p in practicos])
                    presentado = normalizar_presentados(presentado)
                    github  = f"@{alumno['github']}" if len(alumno['github']) else ""
                    nota_1 = alumno.get("nota_1", 0)
                    nota_2 = alumno.get("nota_2", 0) 
                    nota_a = "🟩" if nota_1 >= 45 else "🟨" if nota_1 >= 0 else "🟥"
                    nota_b = "🟩" if nota_2 >= 8  else "🟨" if nota_2 >= 4 else "🟥"
                    promocionable = "Si" if alumno.get("promocionable", False) else "No"
                    oficial       = "Si" if alumno.get("oficial", False)       else "No"
                    if alumno['comision'] == comision:
                        archivo.write(f"- {alumno['legajo']}  {alumno['nombre']:35}  {alumno['telefono']}  {presentado}  {nota_1:2} {nota_a} {nota_2:2} {nota_b} {promocionable:2} {oficial} {github:20}\n")
                
                archivo.write("```\n")
    print(f"| {len(alumnos)} alumnos guardados")
    return alumnos

def calcular_resultado(alumnos):
    """
    Calcula y actualiza el estado de promoción de los alumnos según sus notas y prácticos.
    """
    for alumno in alumnos:
        practicos = [alumno[p] for p in alumno if p.startswith("TP")]
        faltantes = sum(1 for p in practicos if p == "🔴")
        nota_1 = alumno.get("nota_1", 0)
        nota_2 = alumno.get("nota_2", 0)
        if nota_1 >= 45 and nota_2 >= 8 and faltantes == 0:
            alumno["resultado"] = "Promocionado"
        elif faltantes >= 3: # or   nota_1 == 0 or nota_2 == 0:
            alumno["resultado"] = "Libre"
        else:
            alumno["resultado"] = "Regular"
        if not alumno["oficial"]:
            alumno["resultado"] = "Oyente"
        elif not alumno["promocionable"] and alumno["resultado"] == "Promocionado":
            alumno["resultado"] = "Pendiente"

    return alumnos
    
def convertir_vcard(alumnos, archivo_destino="contactos_alumnos.vcf"):
    """
    Convierte una lista de alumnos en un archivo VCard compatible con WhatsApp.
    """

    print(f"> Generando archivo VCard: {archivo_destino}...")
    
    with open(archivo_destino, "w", encoding='utf-8') as archivo:
        for alumno in alumnos:
            if alumno['github'].strip() == "": continue
            nombre_completo = alumno['nombre'].strip()
            partes_nombre = nombre_completo.split(', ')
            
            if len(partes_nombre) == 2:
                apellidos = partes_nombre[0].strip()
                nombres = partes_nombre[1].strip()
            else:
                nombres = nombre_completo
                apellidos = ""
            
            telefono = re.sub(r'[^\d+]', '', alumno['telefono'])
            legajo   = alumno['legajo']
            comision = alumno['comision']
            github   = alumno['github']
            
            vcard = [
                "BEGIN:VCARD",
                "VERSION:3.0",
                f"FN:{nombre_completo}",  # Nombre completo para mostrar
                f"N:{apellidos};{nombres};;;",  # Apellido;Nombre;SegundoNombre;Prefijo;Sufijo
                f"TEL;TYPE=CELL:{telefono}",  # Teléfono celular
                f"NOTE:Legajo: {legajo} - Comision: P4-{comision} - Github: {github}",  # Nota con legajo y comisión
                "END:VCARD"
            ]
            
            # Escribir el VCard al archivo
            archivo.write("\n".join(vcard) + "\n\n")

    print(f"| Archivo generado con {len(alumnos)} contactos.")
    return len(alumnos)


def normalizar(origen='alumnos.md', orden='nombre'):
    """ Lee un archivo markdown con datos de alumnos, los ordena y escribe en otro archivo.
        - orden: `nombre` | `legajo`
    """
    alumnos = leer(origen)
    if orden != "practicos":
        alumnos = sorted(alumnos, key=lambda x: [x['comision'], x[orden]])
    return escribir(alumnos, origen, orden_practicos= orden=="practicos")

def generar_contactos_subir(alumnos):
    """
    Genera un archivo VCard con los contactos de los alumnos para subir a WhatsApp.
    """
    conversion = {"Promocionado": 4, "Pendiente": 3, "Regular": 2, "Libre": 1, "Oyente": 0}
    with open("alumnos_subir.json", "w", encoding='utf-8') as archivo:
        
        for alumno in alumnos:
            alumno['condicion'] = conversion[alumno['resultado']]
            nota = int((alumno.get("nota_1", 0) / 5 + alumno.get("nota_2", 0) ) / 2)
            archivo.write(f"{{ legajo: {alumno['legajo']}, condicion: {alumno['condicion']}, nota: {nota:2}, comision: {alumno['comision']} }},\n")
        

# Ejemplo de uso de la función convertir_vcard
# alumnos = leer('alumnos.md')

# print(f"Se encontraron {len(alumnos)} alumnos")

# # Generar archivo VCard con todos los alumnos
# contactos_generados = convertir_vcard(alumnos, "alumnos.vcf")

# print("Archivos VCard generados exitosamente!")
# print("Puedes importar estos archivos directamente en WhatsApp o en tu aplicación de contactos.")

# %%
# Ejemplo de uso (descomenta para probar)
# carpetas = listar_carpetas_tp("AlejandroDiBattista/tup25-p4", carpeta_base="tp", ref="main")
# print("Carpetas en tp:", carpetas)

# %%
def carpeta(alumno, tp=None): 
    """ Calcula el nombre de la carpeta para un alumno. """
    return f"./tp/{alumno['legajo']} - {alumno['nombre']}{'' if tp is None else f'/tp{tp}'}"


def crear_carpetas(alumnos):
    """Crea carpetas para cada alumno (tp/<legajo> - <nombre>) y un archivo info.txt dentro.
    
    Si existe una carpeta con el mismo legajo pero nombre diferente, la renombra.
    Si no existe carpeta, la crea nueva.
    """
    raiz = Path('../tp')  # Usar la ruta correcta hacia tp/
    raiz.mkdir(parents=True, exist_ok=True)  # Asegurar que el directorio tp existe
    
    print(f"> Procesando {len(alumnos)} alumnos en {raiz}...")
    for a in alumnos:
        # Calcular nombre de carpeta destino (sin el prefijo ../tp/)
        destino = raiz / f"{a['legajo']} - {a['nombre']}"
        
        # Buscar carpetas existentes con el mismo legajo
        carpetas_existentes = list(raiz.glob(f"{a['legajo']} -*"))

        if carpetas_existentes:
            # Si existe al menos una carpeta con este legajo
            carpeta_actual = carpetas_existentes[0]  # Tomar la primera
            
            if carpeta_actual != destino:
                # Si el nombre es diferente, renombrar
                print(f"  Renombrando: {carpeta_actual} \n             > {destino}")
                try:
                    carpeta_actual.rename(destino)
                except Exception as e:
                    print(f"Error al renombrar {carpeta_actual}: {e}")
                    continue
        else:
            # Si no existe carpeta con este legajo, crearla
            print(f"Creando nueva carpeta: {destino}")
            destino.mkdir(parents=True, exist_ok=True)

        # Asegurar que la carpeta existe y escribir/actualizar info.txt
        info_file = destino / "info.txt"
        if not info_file.exists():
            info_content = (
                f"Legajo: {a['legajo']}\n"
                f"Nombre: {a['nombre']}\n"
                f"Teléfono: {a['telefono']}\n"
                f"Comisión: {a['comision']}\n"
            )
            info_file.write_text(info_content, encoding='utf-8')
            print(f"Creado info.txt en: {destino}")


def normalizar_carpetas():
    """ Normaliza el archivo y crea las carpetas correspondientes. """
    alumnos = leer()
    print("> Normalizando nombres de carpetas...")
    crear_carpetas(alumnos)
    print("| Proceso normalización de carpetas finalizado.")

# alumnos = leer()
# normalizar(orden="practicos")
# normalizar_carpetas()

# crear_carpetas(leer())

# %%
def copiar_tp(tp=1, alumnos=None, incluir_ocultos=True, follow_symlinks=False):
    """
    Copia recursivamente todos los archivos y subcarpetas de enunciados/tp{tp}
    a la carpeta correspondiente de cada alumno (tp/<legajo> - <nombre>/tp{tp}).

    - incluir_ocultos: si es False, ignora entradas que comienzan con '.' (p. ej. .DS_Store, .git)
    - follow_symlinks: si es True, copia el contenido al que apunta el symlink; si es False, copia el link como archivo
    """
    if alumnos is None:
        alumnos = leer()

    origen_base = Path(f"./enunciados/tp{tp}")
    if not origen_base.exists():
        print(f"No existe {origen_base}")
        return

    total_archivos = 0
    for a in alumnos:
        destino_base = Path(carpeta(alumno=a, tp=tp))  # ya incluye 'tp/.../tp{tp}'
        destino_base.mkdir(parents=True, exist_ok=True)

        # Recorremos el árbol de 'origen_base' y replicamos estructura + archivos
        for root, dirs, files in os.walk(origen_base):
            root_path = Path(root)

            # Opcional: filtrar carpetas/archivos ocultos
            if not incluir_ocultos:
                dirs[:] = [d for d in dirs if not d.startswith('.')]

            rel = root_path.relative_to(origen_base)
            dest_dir = destino_base / rel
            dest_dir.mkdir(parents=True, exist_ok=True)

            for name in files:
                if not incluir_ocultos and name.startswith('.'):  # p. ej. .DS_Store
                    continue
                src = root_path / name
                dst = dest_dir / name
                try:
                    shutil.copy2(src, dst, follow_symlinks=follow_symlinks)
                    total_archivos += 1
                except Exception as e:
                    print(f"Error copiando {src} -> {dst}: {e}")

    print(f"| Copia finalizada. {len(alumnos)} alumnos, {total_archivos} archivos copiados en total.")


# alumnos = leer()
# crear_carpetas(alumnos)
# copiar_tp(6, alumnos)

# %%
# Gestion de repositorio y Pull Requests

def extraer_legajo_tp(titulo):
    if match:= re.search(r'(\d{5})', titulo):
        legajo = match.group(1)
    else:
        legajo = "00000"

    if match := re.search(r'tp\s*([0-6.,\s]+)', titulo, re.IGNORECASE):
        tp = match.group(1)
        tp = re.sub(r'[,.\s]', '', tp)
        tp = sorted(filter(lambda x: 1 <= x <= 9, map(int, list(tp))))
    else:
        tp = [0]

    return legajo, tp


def normalizar_titulo(titulo, alumnos):
    legajo, tp = extraer_legajo_tp(titulo)
    
    nombre_alumno = next((a['nombre'] for a in alumnos if a['legajo'] == legajo), "Desconocido")
    return f"TP{','.join(map(str,tp))} - {legajo} - {nombre_alumno}"


def cargar_github_user(alumnos):
    print(f"> Cargando usuarios de GitHub en {len(alumnos)} alumnos...")

    practicos = set()
    prs = repo.get_pulls(state='closed', sort='created', base='main')
    for pr in prs:
        # Verificar que el PR fue mergeado, no solo cerrado
        if not pr.merged:
            continue
            
        print(f"✓ PR #{pr.number}: {pr.title} ({pr.commits} commits)")
        legajo, tps = extraer_legajo_tp(pr.title)
        for tp in tps:
            if alumno := next((x for x in alumnos if x['legajo'].strip() == legajo), None):
                alumno["github"] = pr.user.login
                alumno[tp] = 1
            if tp == 0:
                alumno["commits"] = pr.commits
            practicos.add(tp)
            
    for a in alumnos:
        if "commits" not in a:
            a["commits"] = 0
        for c in sorted(practicos):
            if c not in a: 
                a[c] = 0

    print("|")
    return alumnos

## TAG
def contar_pantallas(origen: str | Path = 'emails') -> dict[str, int]:
    camino = Path(origen).expanduser().resolve()
    resultados: dict[str, int] = {}
    
    for sub in sorted(p for p in camino.iterdir() if p.is_dir()):
        legajo = sub.name
        count = sum(1 for f in sub.iterdir() if f.suffix.lower() == '.jpeg')
        resultados[legajo] = count - 1

    return resultados


def averiguar_presentacion_practicos_text():
    with open('lista_pr.txt', 'w', encoding='utf-8') as f:
        prs = repo.get_pulls(state='closed', sort='created', base='main')
        for pr in prs:
            f.write(f"PR #{pr.number}: {pr.title} (merged: {pr.merged})\n")


def averiguar_presentacion_practicos(alumnos):
    practicos = set()
    with open('lista_pr.txt', encoding='utf-8') as f:
        lineas = f.readlines()
        for linea in lineas:
            if not linea.strip(): continue
            
            legajo, tps = extraer_legajo_tp(linea)
            if alumno := next((x for x in alumnos if x['legajo'].strip() == legajo), None):
                for tp in tps:
                    tp = f"TP{tp}"
                    practicos.add(tp)
                    alumno[tp] = 1
    for alumno in alumnos:
        for p in practicos:
            if p not in alumno:
                alumno[p] = 0
    print(f"|</fin> {', '.join(sorted(practicos))}")
    # return alumnos


def normalizar_titulo_pr(estado='open', alumnos=None, simular=False, min=0, max=9999):
    print("> Pull Requests pendientes:")

    open_pulls = repo.get_pulls(state=estado, sort='created', base='main')
    print(f"Total PRs encontrados: {open_pulls.totalCount}")
    for pr in open_pulls:
        if not (min <= pr.number <= max): continue

        pr = repo.get_pull(pr.number)  # Refrescar datos del PR
        nuevo = normalizar_titulo(pr.title, alumnos)
        if pr.title != nuevo:
            if "TP0" in nuevo or "00000" in nuevo:
                print(f"⭕️ #{pr.number:3} → p{pr.title} → {nuevo} ({pr.commits} commits)")
            else:
                print(f" #{pr.number:3}: [{pr.title}]")
                print(f" >> {nuevo} (por {pr.user.login}) {pr.state}{"*" if pr.title != nuevo else ""} - {pr.commits} commits")
                pr.edit(title=nuevo)
        else:
            pass 
            # print(f"- #{pr.number:3}: {nuevo} (por {pr.user.login}) {pr.state} - {pr.commits} commits")

    cols = sorted({c for a in alumnos for c in a.keys() if c.startswith("TP")})

    
    print(f"| fin {cols}")


def aceptar_prs_sin_conflictos():
    open_pulls = repo.get_pulls(state='open', sort='created', base='main')
    print("> Intentando merge de PRs sin conflictos:")
    for pr in open_pulls:
        pr = repo.get_pull(pr.number)       # Refrescar datos
        if pr.mergeable is None:
            time.sleep(5)
            pr = repo.get_pull(pr.number)   # Refrescar
        if pr.mergeable:
            try:
                pr.merge()
                print(f"- ✅ PR #{pr.number:3} mergeado: {pr.title} ({pr.commits} commits)")
            except Exception as e:
                print(f"- ❌ Error al mergear PR #{pr.number:3}: {e}")
        elif pr.mergeable is False:
            print(f"- 👁️ PR #{pr.number:3} tiene conflictos: {pr.title} ({pr.commits} commits)")
        else:
            print(f"- ⏳ Tiempo agotado para PR #{pr.number:3}: {pr.title} ({pr.commits} commits)")
    print("| fin")

# Funciones
# 1. normalizar_pr -> renombra los PRs abiertos con formato estandar
# 2. merge_prs_sin_conflictos -> intenta mergear los PRs sin conflictos

# alumnos = leer()
# normalizar_titulo_pr(estado='open', alumnos=alumnos)
# aceptar_prs_sin_conflictos()
# cargar_github_user(alumnos)

# averiguar_presentacion_practicos_text()
# averiguar_presentacion_practicos(alumnos)
# pantallas = contar_pantallas()
# for a in alumnos:
#     if a['legajo'] in pantallas:
#         a['pantallas'] = pantallas[a['legajo']]
#     else:
#         a['pantallas'] = 0
# escribir(alumnos, "alumnos_tmp.md", orden_practicos=True)
# ""
# escribir(alumnos, "alumnos-con-tp.md", orden_practicos=True)

# Cargar lista de alumnos en un DataFrame y mostrarlo como tabla
# df_alumnos = pd.DataFrame(alumnos)

# df_alumnos

# %%
def descargar_avatar_github(username: str, destino: str | Path = "./avatars", nombre_archivo: str | None = None, token: str | None = None, use_direct_url: bool = True) -> Path:
    destino = Path(destino)
    destino.mkdir(parents=True, exist_ok=True)

    base = nombre_archivo if nombre_archivo else username

    def _guardar(img_resp: requests.Response, ruta_base: Path) -> Path:
        # Elegir extensión por Content-Type
        content_type = img_resp.headers.get("Content-Type", "").lower()
        _ext = ".jpg"
        if "png" in content_type:
            _ext = ".png"
        elif any(x in content_type for x in ["jpeg", "jpg"]):
            _ext = ".jpg"
        elif "gif" in content_type:kaf
            _ext = ".gif"
        destino_archivo = ruta_base.with_suffix(_ext)
        with open(destino_archivo, "wb") as f:
            for chunk in img_resp.iter_content(chunk_size=8192):
                if chunk:
                    f.write(chunk)
        print(f"Avatar guardado en: {destino_archivo}")
        return destino_archivo

    # 1) Intentar descargar directamente desde la URL pública del avatar (sin consumir API core)
    if use_direct_url:
        direct_url = f"https://github.com/{username}.png"
        try:
            img_resp = requests.get(direct_url, stream=True, timeout=30)
            if img_resp.status_code == 200:
                return _guardar(img_resp, destino / base)
            else:
                print(f"No se pudo usar URL directa ({img_resp.status_code}), se intentará API.")
        except Exception as e:
            print(f"Fallo URL directa: {e}. Se intentará API.")

    # 2) Consultar API para obtener avatar_url (con token si está disponible)
    token = token or os.getenv("GITHUB_TOKEN")
    headers = {"Accept": "application/vnd.github+json"}
    if token:
        headers["Authorization"] = f"Bearer {token}"

    url = f"https://api.github.com/users/{username}"
    resp = requests.get(url, headers=headers, timeout=20)
    if resp.status_code == 403:
        # Rate limit excedido
        reset = resp.headers.get("X-RateLimit-Reset")
        if reset and reset.isdigit():
            wait = max(0, int(reset) - int(time.time()) + 2)
            raise RuntimeError(f"Rate limit excedido. Reintentar en ~{wait}s o usar un token válido en GITHUB_TOKEN.")
        raise RuntimeError("Rate limit excedido. Configure GITHUB_TOKEN para aumentar el límite (hasta 5000/hora).")
    resp.raise_for_status()
    data = resp.json()
    avatar_url = data.get("avatar_url")
    if not avatar_url:
        raise RuntimeError(f"No se encontró avatar para el usuario: {username}")

    img_resp = requests.get(avatar_url, stream=True, timeout=30)
    img_resp.raise_for_status()
    return _guardar(img_resp, destino / base)


def bajar_avatars():
    descargados = []

    alumnos = leer()
    for alumno in alumnos:
        gh = (alumno.get('github') or "").strip("@ ")
        if not gh: continue
        destino = Path(carpeta(alumno))  # carpeta devuelve ../tp/<legajo> - <nombre>
        destino.mkdir(parents=True, exist_ok=True)
        nombre_base = str(alumno['legajo'])
        try:
            ruta = descargar_avatar_github(gh, destino=destino, nombre_archivo=nombre_base, use_direct_url=True)
            descargados.append(ruta)
            time.sleep(0.2)  # pequeño throttle para ser buen ciudadano
        except Exception as e:
            print(f"No se pudo bajar avatar de {gh} ({alumno['legajo']}): {e}")

    print(f"Avatares descargados: {len(descargados)}")
# Ejemplo individual:
# bajar_avatars()
# descargar_avatar_github("alejandrodibattista")

# %%
def extraer_chats_whatsapp(origen="/Users/adibattista/Downloads", destino="./interno/chat"):
    """
    Busca archivos ZIP que comiencen con 'what' en la carpeta especificada,
    toma los 2 más recientes (según fecha de creación), extrae el archivo '_chat.txt'
    y lo guarda como 'chat_c1.txt' o 'chat_c3.txt' según el nombre del archivo original.
    
    Parámetros:
    - carpeta_download: ruta donde buscar los archivos ZIP
    - destino: carpeta donde guardar los archivos extraídos
    """
    carpeta = Path(origen)
    if not carpeta.exists():
        print(f"❌ La carpeta {carpeta} no existe")
        return
    
    # Buscar todos los archivos .zip que comiencen con "what"
    archivos_zip = list(carpeta.glob("What*.zip"))
    
    if not archivos_zip:
        print(f"❌ No se encontraron archivos ZIP que comiencen con 'what' en {carpeta}")
        return
    
    print(f"📁 Se encontraron {len(archivos_zip)} archivo(s) ZIP")
    
    # Ordenar por fecha de creación (más reciente primero) y tomar los 2 últimos
    archivos_zip.sort(key=lambda f: f.stat().st_ctime, reverse=True)
    archivos_recientes = archivos_zip[:2]
    
    # Crear carpeta de destino si no existe
    Path(destino).mkdir(parents=True, exist_ok=True)
    
    for archivo_zip in archivos_recientes:
        print(f"\n📦 Procesando: {archivo_zip.name}")
        
        # Determinar si es c1 o c3 según el nombre del archivo
        nombre = archivo_zip.stem.lower()
        if 'c1' in nombre or 'comision1' in nombre or 'comisión1' in nombre:
            comision = 1
        elif 'c3' in nombre or 'comision3' in nombre or 'comisión3' in nombre:
            comision = 3
        else:
            # Si no se puede determinar, usar el número del archivo (1 o 2)
            idx = archivos_recientes.index(archivo_zip) + 1
            comision = 1 if idx == 1 else 3
            print(f"⚠️  No se pudo determinar la comisión del nombre, usando '{comision}'")
        
        try:
            with zipfile.ZipFile(archivo_zip, 'r') as zip_ref:
                # Buscar el archivo que termine en '_chat.txt'
                chat_file = None
                for file_info in zip_ref.namelist():
                    if file_info.endswith('_chat.txt'):
                        chat_file = file_info
                        break
                
                if not chat_file:
                    print(f"   ❌ No se encontró archivo '_chat.txt' en {archivo_zip.name}")
                    continue
                
                # Extraer el contenido del archivo
                with zip_ref.open(chat_file) as f:
                    contenido = f.read()
                
                # Guardar con el nuevo nombre
                archivo_destino = Path(destino) / f"{comision}.txt"
                with open(archivo_destino, 'wb') as f:
                    f.write(contenido)
                
                print(f"   ✅ Extraído: {chat_file}")
                print(f"   💾 Guardado como: {archivo_destino}")
                
        except zipfile.BadZipFile:
            print(f"   ❌ Error: {archivo_zip.name} no es un archivo ZIP válido")
        except Exception as e:
            print(f"   ❌ Error al procesar {archivo_zip.name}: {e}")
    
    print("\n✨ Proceso completado")

# Ejecutar la función

def extraer_asistencias(lineas, comision=None):
    patron = re.compile(r"^\[(\d{1,2}/\d{1,2}/\d{2}),\s*(\d{1,2}:\d{2}:\d{2})\]\s*(.*?):")
    
    registros = []
    for linea in lineas:
        linea = linea.strip()
        linea = linea.replace("‎", "")
        if not linea:
            continue
        if match := patron.match(linea):
            fecha_str, hora_str, nombre = match.groups()
            fecha = datetime.strptime(fecha_str, "%d/%m/%y").date()
            registros.append({"fecha": fecha.isoformat(), "hora": hora_str, "nombre": nombre, "comision": comision})
        else:
            # print(f"No coincide: {linea}")
            pass

    return registros

def leer_chat(comision: int ):
    with open(f"./interno/chat/c{comision}.txt", "r", encoding="utf-8") as archivo:
        lineas = archivo.readlines()
    return extraer_asistencias(lineas, comision)

# extraer_chats_whatsapp()

# alumnos = leer()
# convertir_vcard(alumnos, 'contactos.vcf')
# asistencias = []
# asistencias += leer_chat(1)
# asistencias += leer_chat(3)
# # asistencias

# %%
def leer_promocionables_tsv(origen="./promocionables.tsv", programacion = False, color = False):
    """
    Lee un archivo TSV con legajos promocionables y devuelve una lista de legajos.
    """
    legajos = {}
    print(f"== Leyendo promocionables desde {origen} | Programación: {'Si' if programacion else 'No'} | Color: {'Si' if color else 'No'} ==")
    with open(origen, "r", encoding='utf-8') as archivo:
        for linea in archivo:
            linea = linea.strip()
            if not linea or "legajo" in linea: continue
            partes = linea.split("\t")
            if len(partes) == 5:
                legajo = int(partes[0])
                es_programacion = partes[2] == "P4"
                es_color        = partes[4].lower() == "v"
                promocionable = (not programacion or es_programacion) and (not color or es_color)
                legajos[legajo] = legajos.get(legajo, False) or promocionable
                # if promocionable:
                #     print(f"✓ Legajo {legajo}: Prog={'Si' if es_programacion else 'No'} Color={'Si' if es_color else 'No'} -> Promo={'Si' if promocionable else 'No'}")
            else: 
                print(f"⚠️  Línea inválida en {origen}: {linea}")
                continue
    return legajos


def leer_promocionables(origen="./promocionables.md"):
    """
    Lee el archivo promocionables.md y devuelve una lista de todos los legajos promocionables.
    """
    legajos = {}
    si = False
    with open(origen, "r", encoding='utf-8') as archivo:
        for linea in archivo:
            linea = linea.strip()
            if not linea: continue
            
            if linea.startswith("## Si") or linea.startswith("## No"):
                si = True
            elif linea.startswith("## No"):
                # si = False
                si = True # Sin ningun filtro... si esta en el listado es promocionable
            if linea.startswith("- "):
                if partes:= linea.split():
                    legajo = int(partes[1])
                    if legajo in legajos:
                        anterior = legajos[legajo]
                        if anterior != si:
                            print(f"⚠️  Legajo {legajo} cambia de estado {anterior} -> {si}")
                    legajos[legajo] = si
    return legajos

print("Leyendo alumnos y estados oficiales/promocionables...")
alumnos = leer("alumnos_temporal.md")
print(f"Total alumnos: {len(alumnos)}")

promocionables = leer_promocionables("./promocionables.md")
oficiales      = leer_promocionables("./listado-oficial.md")

print("\n== Legajos promocionables ==")
promo = leer_promocionables_tsv("./promocionables.tsv", programacion=True, color=True)
print(f"  Materia y color: {sum(1 for v in promo.values() if v):2}")

promo = leer_promocionables_tsv("./promocionables.tsv", programacion=True, color=False)
print(f"  Solo materia   : {sum(1 for v in promo.values() if v):2}")

promo = leer_promocionables_tsv("./promocionables.tsv", programacion=False, color=True)
print(f"  Solo color     : {sum(1 for v in promo.values() if v):2}")

promo = leer_promocionables_tsv("./promocionables.tsv", programacion=False, color=False)
print(f"  Total legajos  : {sum(1 for v in promo.values() if v):2}")


for alumno in alumnos:
    legajo = int(alumno['legajo'])
    alumno['promocionable'] = promocionables.get(legajo, False)
    alumno['oficial']       = oficiales.get(legajo, False)
    
calcular_resultado(alumnos)
# print("Resumen de resultados:")
# resultados = set(a['resultado'] for a in alumnos)
# for r in resultados:
#     cuenta = sum(1 for a in alumnos if a['resultado'] == r)
#     print(f"- {r:20}: {cuenta:2}")
# ==>
escribir(alumnos, "alumnos_2.md", orden_practicos=False, promocionables=True)
generar_contactos_subir(alumnos)
