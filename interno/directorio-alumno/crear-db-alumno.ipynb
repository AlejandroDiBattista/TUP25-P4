# %% [markdown]
# # Generar base de datos de alumnos

# %%
# %pip install python-box
import re
import json
import os

def leer_todos(archivo):
    with open(archivo, 'r', encoding='utf-8') as f:
        alumnos = {}
        curso   = None
        estado  = None
        año = 0
        materia = ""
        comision = ""

        for linea in f:
            linea = linea.strip()
            if not linea or linea.startswith('# '): 
                continue
            if linea.startswith('## '):
                curso = linea[7:].strip()
                año, materia, comision = curso.split('-')
                año = 2000 + int(año)
                estado = None
            elif linea.startswith('### '):
                estado = linea[4:].strip()
            elif "-" in linea:
                legajo, nombre = map(str.strip, linea.split('-'))
                if legajo not in alumnos:
                    alumnos[legajo] = {'legajo': legajo, 'nombre': nombre, 'cursos': {}}
                alumnos[legajo]["cursos"][curso] = {"año": año, "materia": materia, "comision": comision, "estado": estado}
        
        return alumnos

def leer_cursando(origen: str = "../../alumnos.md") -> list:
    """
    Lee un archivo markdown con datos de alumnos y devuelve una lista de diccionarios.
    """

    print(f"> Leyendo {origen}...")
    salida, comision = [], ""
    with open(origen, "r", encoding='utf-8') as archivo:
        for linea in archivo:
            if not linea.strip():
                continue

            # Normalizar espacios iniciales para aceptar tanto '- ...' como ' - ...'
            sline = linea.lstrip()

            if sline.startswith("##"):
                # Tomar último caracter numérico de la cabecera (p. ej. '## Comisión 1')
                comision = "C" + sline.strip("# \n")[-1]

            if sline.startswith("- "):
                sline = sline.replace("@","")
                partes = re.split(r"\s{2,}", sline.strip("- \n@"))
                if len(partes) < 5:
                    partes.append("")
                legajo, nombre, telefono, practicos, github = partes
                valores = [legajo, nombre, telefono, github, comision]
                valores = dict(zip('legajo nombre telefono github comision'.split(), valores))

                for i, p in enumerate(practicos, 1):
                    if p == "0":  p = "🔴"
                    if p == "⚪️": p = "🔴"
                    if p == "1":  p = "🟢"
                    valores[f"TP{i}"] = p

                salida.append(valores)
    print(f"| {len(salida)} alumnos leídos.")
    return sorted(salida, key=lambda x: [x['comision'], x['legajo']])


def agregar_telefono_github(archivo, alumnos):
    telefonos = {}
    with open(archivo, 'r', encoding='utf-8') as f:
        for linea in f:
            if not linea.strip() or linea.startswith("#"): continue
            linea += '  '  # Asegura al menos dos espacios al final
            parts = re.split(r'\s{2,}', linea.strip())
            parts += [''] * (4 - len(parts))
            legajo, nombre, telefono, github = [p.strip() for p in parts[:4]]
            if legajo in alumnos:
                alumnos[legajo]['telefono'] = telefono
                alumnos[legajo]['github'] = github

    return telefonos


# ==>
def listar_alumnos(alumnos, minimo=1):
    students_iterable = alumnos.values() if isinstance(alumnos, dict) else alumnos

    resultado = []
    for alumno in students_iterable:
        cursos = alumno.get('cursos', []) if isinstance(alumno, dict) else []
        if len(cursos) >= minimo:
            resultado.append(alumno)

    if not resultado:
        print(f"No hay alumnos que hayan estado al menos en {minimo} cursos.")
    else:
        for a in resultado:
            print(f"{a.get('legajo','?')} - {a.get('nombre','?')} ({len(a.get('cursos',{}))} cursos)")
            for c in a.get('cursos', []):
                print(f"  {c['año']} - {c['materia']} - {c['comision']} - estado: {c['estado']}")
            print()

def generar_agenda(alumnos, archivo="agenda.vcf"):
    with open(archivo, 'w', encoding='utf-8') as f:
        for alumno in alumnos.values() if isinstance(alumnos, dict) else alumnos:
            vcard = generar_vcard(alumno)
            f.write(vcard + "\n")
    
def generar_vcard(alumno):
    nombre_completo = alumno.get('nombre', 'Desconocido')
    apellidos, nombres = nombre_completo.split(',', 1)
    telefono = alumno.get('telefono', '')
    github   = alumno.get('github', '')
    legajo   = alumno.get('legajo', '00000')
    cursos   = alumno.get('cursos', [])
    texto = [ f"Año: {c['año']} Materia: {c['materia']} Comisión {c['comision']} Estado: {c['estado']}" for c in cursos ]

    vcard = [
                "BEGIN:VCARD",
                "VERSION:3.0",
                f"FN:{nombre_completo}",        # Nombre completo para mostrar
                f"N:{apellidos};{nombres};;;",  # Apellido;Nombre;SegundoNombre;Prefijo;Sufijo
                f"TEL;TYPE=CELL:{telefono}",    # Teléfono celular
                f"NOTE:Legajo: {legajo} - Github: {github}",  # Nota con legajo y comisión
                f"{' | '.join(texto)}",    # Nota con cursos
                "END:VCARD"
            ]
    
    return "\n".join(vcard)

def agregar_practicos(cursando, alumnos):
    for alumno in cursando:
        legajo = alumno['legajo']
        if legajo in alumnos:
            original = alumnos[legajo]
            for curso in original.get('cursos', []):
                if curso['estado'] == 'Cursando':
                    for key, value in alumno.items():
                        if key.startswith('TP'):
                            curso[key] = value


def existe_perfil(legajo):
    return os.path.exists(f"./deploy/perfil/{legajo}.jpeg")
    
def normalizar_materias(alumnos):
    for alumno in alumnos.values():
        for curso in alumno.get('cursos', {}).values():
            materia = curso['materia'].lower()
            if materia in ['lab1', 'lab2', 'lab3', 'lab4']:
                curso['materia'] = materia.replace('lab', 'Laboratorio ')
            elif materia in ['pro1', 'pro2', 'pro3', 'pro4']:
                curso['materia'] = materia.replace('pro', 'Programación ')
            curso["codigo"] = f"{materia[0]}{materia[-1]}".upper()
        alumno['cursos'] = list(alumno.get('cursos', {}).values())

alumnos = leer_todos('./alumnos-totales.md')
agregar_telefono_github('telefonos.md', alumnos)
for legajo, alumno in alumnos.items():
    alumno['foto'] = existe_perfil(legajo)
# agregar_practicos(leer_cursando(), alumnos)
normalizar_materias(alumnos)
listar_alumnos(alumnos, minimo=0)

with open("alumnos.vcf", "w", encoding="utf-8") as f:
    generar_agenda(alumnos, archivo=f.name)

with open("./deploy/alumnos.json", "w", encoding="utf-8") as f:
    f.write(json.dumps(alumnos, indent=2, ensure_ascii=False))
alumnos
# Out:
# 58931 - Cabrera, Lucas Nahuel (1 cursos)
#   2024 - Laboratorio 3 - C3 - estado: Promocionado
#
# 59022 - Camaño Terán, Nicolás (1 cursos)
#   2024 - Laboratorio 3 - C3 - estado: Promocionado
#
# 58889 - Capó, Mauricio Nicolás (1 cursos)
#   2024 - Laboratorio 3 - C3 - estado: Promocionado
#
# 58770 - Carabajal, Ariadna Micael (1 cursos)
#   2024 - Laboratorio 3 - C3 - estado: Promocionado
#
# 59046 - Carrizo, Angel Nahuel (1 cursos)
#   2024 - Laboratorio 3 - C3 - estado: Promocionado
#
# 58925 - Castillo, Martina (1 cursos)
#   2024 - Laboratorio 3 - C3 - estado: Promocionado
#
# 59016 - Catania, Franco Mauricio (1 cursos)
#   2024 - Laboratorio 3 - C3 - estado: Promocionado
#
# 58813 - Cervera, Diego Octavio (1 cursos)
#   2024 - Laboratorio 3 - C3 - estado: Promocionado
#
# 59379 - Charkiewicz, Carolina Est (1 cursos)
#   2024 - Laboratorio 3 - C3 - estado: Promocionado
#
# 
1 cursos)
#   2025 - Programación 3 - C5 - estado: Libre
#
# 61858 - Perez, Facundo Agustin (1 cursos)
#   2025 - Programación 3 - C5 - estado: Libre
#
# 62612 - Campos, Julieta Antonella (1 cursos)
#   2025 - Programación 3 - C5 - estado: Libre
#
# 61131 - Agostino Colombres, Juan Manuel (1 cursos)
#   2025 - Programación 4 - C1 - estado: Promocionado
#
# 61565 - Carrizo, Mauro (1 cursos)
#   2025 - Programación 4 - C1 - estado: Promocionado
#
# 61236 - Drachenberg, Franco Eduardo (1 cursos)
#   2025 - Programación 4 - C1 - estado: Promocionado
#
# 61198 - Ferreyra Appas, Santiago Nicolás (1 cursos)
#   2025 - Programación 4 - C1 - estado: Promocionado
#
# 61167 - Giacobbe, Franco (1 cursos)
#   2025 - Programación 4 - C1 - estado: Promocionado
#
# 61073 - González Chavez, Rodrigo (1 cursos)
#   2025 - Programación 4 - C1 - estado: Promocionado
#
# 61120 - Guerrero, Ana Sofía (1 cursos)
#   2025 - Programación 4 - C1 - estado: Promocionado
#
# 54911 - Jatib, Rodrigo Gabriel (1 cursos)
#   2025 - Programación 4 - C1 - estado: Promocionado
#
# 61035 - Ledesma, Paulo Marcelo (1 cursos)
#   2025 - Programación 4 - C1 - estado: Promocionado
#
# 61115 - Ledesma, Santiago Esteban (1 cursos)
#   2025 - Programación 4 - C1 - estado: Promocionado
#
# 61335 - León, Lucas Ismael (1 cursos)
#   2025 - Programación 4 - C1 - estado: Promocionado
#
# 61911 - Llanos, Luciano (1 cursos)
#   2025 - Programación 4 - C1 - estado: Promocionado
#
# 61993 - Medina, Juan Ignacio (1 cursos)
#   2025 - Programación 4 - C1 - estado: Promocionado
#
# 61338 - Morales, Juan Daniel (1 cursos)
#   2025 - Programación 4 - C1 - estado: Promocionado
#
# 61046 - Ponce, Luz Micaela (1 cursos)
#   2025 - Programación 4 - C1 - estado: Promocionado
#
# 61033 - Quiroga, José María (1 cursos)
#   2025 - Programación 4 - C1 - estado: Promocionado
#
# 62175 - Quiroga, Marcela Noemí (1 cursos)
#   2025 - Programación 4 - C1 - estado: Promocionado
#
# 61084 - Ramírez, Leonardo (1 cursos)
#   2025 - Programación 4 - C1 - estado: Promocionado
#
# 61315 - Robles, Thiago (1 cursos)
#   2025 - Programación 4 - C1 - estado: Promocionado
#
# 61468 - Samaniego, Esteban Maximiliano (1 cursos)
#   2025 - Programación 4 - C1 - estado: Promocionado
#
# 61240 - Timo, Héctor Gabriel (1 cursos)
#   2025 - Programación 4 - C1 - estado: Promocionado
#
# 61725 - Villagra, Jorge Sebastián (1 cursos)
#   2025 - Programación 4 - C1 - estado: Promocionado
#
# 61551 - Díaz Valdez, Ignacio (1 cursos)
#   2025 - Programación 4 - C1 - estado: Regular
#
# 61472 - Díaz, Julieta Camila (1 cursos)
#   2025 - Programación 4 - C1 - estado: Regular
#
# 62318 - Quiroga Castro, Lisandro (1 cursos)
#   2025 - Programación 4 - C1 - estado: Regular
#
# 61337 - Díaz, Christian Gabriel (1 cursos)
#   2025 - Programación 4 - C1 - estado: Libre
#
# 61805 - Jerez, Tomás (1 cursos)
#   2025 - Programación 4 - C1 - estado: Libre
#
# 61719 - Amoedo, Pablo Isaías (1 cursos)
#   2025 - Programación 4 - C3 - estado: Promocionado
#
# 61150 - Molina Navarro, Juan Martín (1 cursos)
#   2025 - Programación 4 - C3 - estado: Promocionado
# {'58931': {'legajo': '58931',
#   'nombre': 'Cabrera, Lucas Nahuel',
#   'cursos': [{'año': 2024,
#     'materia': 'Laboratorio 3',
#     'comision': 'C3',
#     'estado': 'Promocionado',
#     'codigo': 'L3'}],
#   'foto': False},
#  '59022': {'legajo': '59022',
#   'nombre': 'Camaño Terán, Nicolás',
#   'cursos': [{'año': 2024,
#     'materia': 'Laboratorio 3',
#     'comision': 'C3',
#     'estado': 'Promocionado',
#     'codigo': 'L3'}],
#   'foto': False},
#  '58889': {'legajo': '58889',
#   'nombre': 'Capó, Mauricio Nicolás',
#   'cursos': [{'año': 2024,
#     'materia': 'Laboratorio 3',
#     'comision': 'C3',
#     'estado': 'Promocionado',
#     'codigo': 'L3'}],
#   'foto': False},
#  '58770': {'legajo': '58770',
#   'nombre': 'Carabajal, Ariadna Micael',
#   'cursos': [{'año': 2024,
#     'materia': 'Laboratorio 3',
#     'comision': 'C3',
#     'estado': 'Promocionado',
#     'codigo': 'L3'}],
#   'foto': False},
#  '59046': {'legajo': '59046',
#   'nombre': 'Carrizo, Angel Nahuel',
#   'cursos': [{'año': 2024,
#     'materia': 'Laboratorio 3',
#     'comision': 'C3',
#     'estado': 'Promocionado',
#     'codigo': 'L3'}],
#   'foto': False},
#  '58925': {'legajo': '58925',
#   'nombre': 'Castillo, Martina',
#   'cursos': [{'año': 2024,
#     'materia': 'Laboratorio 3',
#     'comision': 'C3',
#     'estado': 'Promocionado',
#     'codigo': 'L3'}],
#   'foto': False},
#  '59016': {'legajo': '59016',
#   'nombre': 'Catania, Franco Mauricio',
#   'cursos': [{'año': 2024,
#     'materia': 'Laboratorio 3',
#     'comision': 'C3',
#     'estado': 'Promocionado',
#     'codigo': 'L3'}],
#   'foto': False},
#  '58813': {'legajo': '58813',
#   'nombre': 'Cervera, Diego Octavio',
#   'cursos': [{'año': 2024,
#     'materia': 'Laboratorio 3',
#     'comision': 'C3',
#     'estado': 'Promocionado',
#     'codigo': 'L3'}],
#   'foto': False},
#  '59379': {'legajo': '59379',
#   'nombre': 'Charkiewicz, Carolina Est',
#   'cursos': [{'año': 2024,
#     'materia': 'Laboratorio 3',
#     'comision': 'C3',
#     'estado': 'Promocionado',
#     'codigo': 'L3'}],
#   'foto': False},
#  '59347': {'legajo': '59347',
#   'nombre': 'Chein, Amir Elias',
#   'cursos': [{'año': 2024,
#     'materia': 'Laboratorio 3',
#     'comision': 'C3',
#     'estado': 'Promocionado',
#     'codigo': 'L3'}],
#   'foto': False},
#  '59315': {'legajo': '59315',
#   'nombre': 'Chein, Santiago',
#   'cursos': [{'año': 2024,
#     'materia': 'Laboratorio 3',
#     'comision': 'C3',
#     'estado': 'Promocionado',
#     'codigo': 'L3'}],
#   'foto': False},
#  '59083': {'legajo': '59083',
#   'nombre': 'Cuellar, José Omar',
#   'cursos': [{'año': 2024,
#     'materia': 'Laboratorio 3',
#     'comision': 'C3',
#     'estado': 'Promocionado',
#     'codigo': 'L3'}],
#   'foto': False},
#  '59063': {'legajo': '59063',
#   'nombre': 'Cuevas, Matias Sebastián',
#   'cursos': [{'año': 2024,
#     'materia': 'Laboratorio 3',
#     'comision': 'C3',
#     'estado': 'Promocionado',
#     'codigo': 'L3'}],
#   'foto': False},
#  '58888': {'legajo': '58888',
#   'nombre': 'Diaz Gómez, Andrés Dario',
#   'cursos': [{'año': 2024,
#     'materia': 'Laboratorio 3',
#     'comision': 'C3',
#     'estado': 'Promocionado',
#     'codigo': 'L3'}],
#   'foto': False},
#  '55249': {'legajo': '55249',
#   'nombre': 'Fernandez, Gonzalo Tomas',
#   'cursos': [{'año': 2024,
#     'materia': 'Laboratorio 3',
#     'comision': 'C3',
#     'estado': 'Promocionado',
#     'codigo': 'L3'},
#    {'año': 2024,
#     'materia': 'Laboratorio 4',
#     'comision': 'C5',
#     'estado': 'Pendiente',
#     'codigo': 'L4'}],
#   'foto': False},
#  '57565': {'legajo': '57565',
#   'nombre': 'Heredia, Fabricio Nicolás',
#   'cursos': [{'año': 2024,
#     'materia': 'Laboratorio 3',
#     'comision': 'C3',
#     'estado': 'Promocionado',
#     'codigo': 'L3'}],
#   'foto': False},
#  '59184': {'legajo': '59184',
#   'nombre': 'Lucena, Matias Leandro',
#   'cursos': [{'año': 2024,
#     'materia': 'Laboratorio 3',
#     'comision': 'C3',
#     'estado': 'Promocionado',
#     'codigo': 'L3'},
#    {'año': 2024,
#     'materia': 'Laboratorio 4',
#     'comision': 'C5',
#     'estado': 'Pendiente',
#     'codigo': 'L4'}],
#   'foto': False},
#  '59060': {'legajo': '59060',
#   'nombre': 'Martinez, Maira',
#   'cursos': [{'año': 2024,
#     'materia': 'Laboratorio 3',
#     'comision': 'C3',
#     'estado': 'Promocionado',
#     'codigo': 'L3'}],
#   'foto': False},
#  '59550': {'legajo': '59550',
#   'nombre': 'Osores Medina, Selena Pau',
#   'cursos': [{'año': 2024,
#     'materia': 'Laboratorio 3',
#     'comision': 'C3',
#     'estado': 'Promocionado',
#     'codigo': 'L3'}],
#   'foto': False},
#  '59092': {'legajo': '59092',
#   'nombre': 'Perez, Luciano Damian',
#   'cursos': [{'año': 2024,
#     'materia': 'Laboratorio 3',
#     'comision': 'C3',
#     'estado': 'Promocionado',
#     'codigo': 'L3'}],
#   'foto': False},
#  '58884': {'legajo': '58884',
#   'nombre': 'Salazar, Agustina Ximena',
#   'cursos': [{'año': 2024,
#     'materia': 'Laboratorio 3',
#     'comision': 'C3',
#     'estado': 'Promocionado',
#     'codigo': 'L3'}],
#   'foto': False},
#  '58881': {'legajo': '58881',
#   'nombre': 'Sosa Juarez, Malena Lujan',
#   'cursos': [{'año': 2024,
#     'materia': 'Laboratorio 3',
#     'comision': 'C3',
#     'estado': 'Promocionado',
#     'codigo': 'L3'}],
#   'foto': False},
#  '58771': {'legajo': '58771',
#   'nombre': 'Calvo Maderuelo, Carlos M',
#   'cursos': [{'año': 2024,
#     'materia': 'Laboratorio 3',
#     'comision': 'C3',
#     'estado': 'Regular',
#     'codigo': 'L3'}],
#   'foto': False},
#  '55839': {'legajo': '55839',
#   'nombre': 'Castillo, Ignacio Agustín',
#   'cursos': [{'año': 2024,
#     'materia': 'Laboratorio 3',
#     'comision': 'C3',
#     'estado': 'Regular',
#     'codigo': 'L3'}],
#   'foto': False},
#  '59027': {'legajo': '59027',
#   'nombre': 'Chaves, Gonzalo Martín',
#   'cursos': [{'año': 2024,
#     'materia': 'Laboratorio 3',
#     'comision': 'C3',
#     'estado': 'Regular',
#     'codigo': 'L3'}],
#   'foto': False},
#  '58768': {'legajo': '58768',
#   'nombre': 'Cordoba, Ignacio Leandro',
#   'cursos': [{'año': 2024,
#     'materia': 'Laboratorio 3',
#     'comision': 'C3',
#     'estado': 'Regular',
#     'codigo': 'L3'}],
#   'foto': False},
#  '58780': {'legajo': '58780',
#   'nombre': 'Coronel, Juan Carlos',
#   'cursos': [{'año': 2024,
#     'materia': 'Laboratorio 3',
#     'comision': 'C3',
#     'estado': 'Regular',
#     'codigo': 'L3'}],
#   'foto': False},
#  '58937': {'legajo': '58937',
#   'nombre': 'Coronel, Lucas Francisco',
#   'cursos': [{'año': 2024,
#     'materia': 'Laboratorio 3',
#     'comision': 'C3',
#     'estado': 'Regular',
#     'codigo': 'L3'}],
#   'foto': False},
#  '59019': {'legajo': '59019',
#   'nombre': 'Corral Garcia, Mario Maxi',
#   'cursos': [{'año': 2024,
#     'materia': 'Laboratorio 3',
#     'comision': 'C3',
#     'estado': 'Regular',
#     'codigo': 'L3'}],
#   'foto': False},
#  '58939': {'legajo': '58939',
#   'nombre': 'Cruz, Francisco Sebastian',
#   'cursos': [{'año': 2024,
#     'materia': 'Laboratorio 3',
#     'comision': 'C3',
#     'estado': 'Regular',
#     'codigo': 'L3'}],
#   'foto': False},
#  '59075': {'legajo': '59075',
#   'nombre': 'Delgado, Fabricio Tobias',
#   'cursos': [{'año': 2024,
#     'materia': 'Laboratorio 3',
#     'comision': 'C3',
#     'estado': 'Regular',
#     'codigo': 'L3'}],
#   'foto': False},
#  '59185': {'legajo': '59185',
#   'nombre': 'Diaz Ghiggia, Guillermo',
#   'cursos': [{'año': 2024,
#     'materia': 'Laboratorio 3',
#     'comision': 'C3',
#     'estado': 'Regular',
#     'codigo': 'L3'}],
#   'foto': False},
#  '58844': {'legajo': '58844',
#   'nombre': 'Diaz Gonzalez, Nahuel Ale',
#   'cursos': [{'año': 2024,
#     'materia': 'Laboratorio 3',
#     'comision': 'C3',
#     'estado': 'Regular',
#     'codigo': 'L3'}],
#   'foto': False},
#  '58763': {'legajo': '58763',
#   'nombre': 'Donelli, Luciano',
#   'cursos': [{'año': 2024,
#     'materia': 'Laboratorio 3',
#     'comision': 'C3',
#     'estado': 'Regular',
#     'codigo': 'L3'}],
#   'foto': False},
#  '59438': {'legajo': '59438',
#   'nombre': 'Martin, Leonardo Javier',
#   'cursos': [{'año': 2024,
#     'materia': 'Laboratorio 3',
#     'comision': 'C3',
#     'estado': 'Regular',
#     'codigo': 'L3'}],
#   'foto': False},
#  '55883': {'legajo': '55883',
#   'nombre': 'Pedraza, Leonardo Miguel',
#   'cursos': [{'año': 2024,
#     'materia': 'Laboratorio 3',
#     'comision': 'C3',
#     'estado': 'Regular',
#     'codigo': 'L3'}],
#   'foto': False},
#  '58905': {'legajo': '58905',
#   'nombre': 'Sueldo, Leandro Antonio',
#   'cursos': [{'año': 2024,
#     'materia': 'Laboratorio 3',
#     'comision': 'C3',
#     'estado': 'Regular',
#     'codigo': 'L3'}],
#   'foto': False},
#  '50792': {'legajo': '50792',
#   'nombre': 'Tula Nelegatti, Agustin',
#   'cursos': [{'año': 2024,
#     'materia': 'Laboratorio 3',
#     'comision': 'C3',
#     'estado': 'Regular',
#     'codigo': 'L3'}],
#   'foto': False},
#  '57605': {'legajo': '57605',
#   'nombre': 'Auad, Gerónimo',
#   'cursos': [{'año': 2024,
#     'materia': 'Laboratorio 3',
#     'comision': 'C3',
#     'estado': 'Libre',
#     'codigo': 'L3'}],
#   'foto': False},
#  '59204': {'legajo': '59204',
#   'nombre': 'Aybar, Anibal Cesar Daniel',
#   'cursos': [{'año': 2024,
#     'materia': 'Laboratorio 3',
#     'comision': 'C3',
#     'estado': 'Libre',
#     'codigo': 'L3'}],
#   'foto': False},
#  '59181': {'legajo': '59181',
#   'nombre': 'Castro, Maria Belén',
#   'cursos': [{'año': 2024,
#     'materia': 'Laboratorio 3',
#     'comision': 'C3',
#     'estado': 'Libre',
#     'codigo': 'L3'}],
#   'foto': False},
#  '57534': {'legajo': '57534',
#   'nombre': 'Delani, Luca',
# ...
#     'codigo': 'P3'}],
#   'telefono': '(381)689-6591',
#   'github': '@agusmatas004',
#   'foto': False},
#  '61072': {'legajo': '61072',
#   'nombre': 'Casavalle Castillo, Bruno',
#   'cursos': [{'año': 2025,
#     'materia': 'Programación 3',
#     'comision': 'C5',
#     'estado': 'Pendiente',
#     'codigo': 'P3'}],
#   'telefono': '(381)353-4422',
#   'github': '@BrunoLCC',
#   'foto': False},
#  '61122': {'legajo': '61122',
#   'nombre': 'Molina Hernando, Nahuel',
#   'cursos': [{'año': 2025,
#     'materia': 'Programación 3',
#     'comision': 'C5',
#     'estado': 'Pendiente',
#     'codigo': 'P3'}],
#   'telefono': '(381)619-4179',
#   'github': '@Nahumolher',
#   'foto': False},
#  '61140': {'legajo': '61140',
#   'nombre': 'Perez, Fernando Alberto',
#   'cursos': [{'año': 2025,
#     'materia': 'Programación 3',
#     'comision': 'C5',
#     'estado': 'Pendiente',
#     'codigo': 'P3'}],
#   'telefono': '(381)643-2069',
#   'github': '@ferchucasla',
#   'foto': False},
#  '61189': {'legajo': '61189',
#   'nombre': 'Buzza, Juliana',
#   'cursos': [{'año': 2025,
#     'materia': 'Programación 3',
#     'comision': 'C5',
#     'estado': 'Pendiente',
#     'codigo': 'P3'}],
#   'telefono': '(381)524-7391',
#   'github': '@julianabuzza',
#   'foto': False},
#  '61218': {'legajo': '61218',
#   'nombre': 'Liendo, Lautaro',
#   'cursos': [{'año': 2025,
#     'materia': 'Programación 3',
#     'comision': 'C5',
#     'estado': 'Pendiente',
#     'codigo': 'P3'}],
#   'telefono': '(381)213-0484',
#   'github': '@LautaroLiendo',
#   'foto': False},
#  '61247': {'legajo': '61247',
#   'nombre': 'Medici Assaf, Abril',
#   'cursos': [{'año': 2025,
#     'materia': 'Programación 3',
#     'comision': 'C5',
#     'estado': 'Pendiente',
#     'codigo': 'P3'}],
#   'telefono': '(381)352-5720',
#   'github': '@Abihdp',
#   'foto': False},
#  '61314': {'legajo': '61314',
#   'nombre': 'Morales, Ignacio Agustin',
#   'cursos': [{'año': 2025,
#     'materia': 'Programación 3',
#     'comision': 'C5',
#     'estado': 'Pendiente',
#     'codigo': 'P3'}],
#   'telefono': '(381)222-0501',
#   'github': '@agucho03',
#   'foto': False},
#  '61345': {'legajo': '61345',
#   'nombre': 'Caro, Tobias',
#   'cursos': [{'año': 2025,
#     'materia': 'Programación 3',
#     'comision': 'C5',
#     'estado': 'Pendiente',
#     'codigo': 'P3'}],
#   'telefono': '(297)500-3076',
#   'github': '@Ultraliv3',
#   'foto': False},
#  '61496': {'legajo': '61496',
#   'nombre': 'Parache, Ariana Agustina',
#   'cursos': [{'año': 2025,
#     'materia': 'Programación 3',
#     'comision': 'C5',
#     'estado': 'Pendiente',
#     'codigo': 'P3'}],
#   'telefono': '(381)640-2374',
#   'github': '@AgusParache',
#   'foto': False},
#  '61535': {'legajo': '61535',
#   'nombre': 'Mainardi, Facundo',
#   'cursos': [{'año': 2025,
#     'materia': 'Programación 3',
#     'comision': 'C5',
#     'estado': 'Pendiente',
#     'codigo': 'P3'}],
#   'telefono': '(381)584-1265',
#   'github': '@Virus2022p',
#   'foto': False},
#  '61540': {'legajo': '61540',
#   'nombre': 'Garcia Mc Guiness, Gonzalo',
#   'cursos': [{'año': 2025,
#     'materia': 'Programación 3',
#     'comision': 'C5',
#     'estado': 'Pendiente',
#     'codigo': 'P3'}],
#   'telefono': '(381)606-4655',
#   'github': '@Gonz4McGuiness',
#   'foto': False},
#  '61588': {'legajo': '61588',
#   'nombre': 'Mussa, Agustín',
#   'cursos': [{'año': 2025,
#     'materia': 'Programación 3',
#     'comision': 'C5',
#     'estado': 'Pendiente',
#     'codigo': 'P3'}],
#   'telefono': '(381)394-9538',
#   'github': '@AgustinCJM',
#   'foto': False},
#  '61611': {'legajo': '61611',
#   'nombre': 'Coronel, Julieta Antonella',
#   'cursos': [{'año': 2025,
#     'materia': 'Programación 3',
#     'comision': 'C5',
#     'estado': 'Pendiente',
#     'codigo': 'P3'}],
#   'telefono': '(381)477-0368',
#   'github': '@julieta2815a',
#   'foto': False},
#  '61644': {'legajo': '61644',
#   'nombre': 'Ortega, Fernando Nicolas',
#   'cursos': [{'año': 2025,
#     'materia': 'Programación 3',
#     'comision': 'C5',
#     'estado': 'Pendiente',
#     'codigo': 'P3'}],
#   'telefono': '(381)646-2643',
#   'github': '@NicolasOrtega851',
#   'foto': False},
#  '61848': {'legajo': '61848',
#   'nombre': 'Mazza Leon, Fabrizio Lautaro',
#   'cursos': [{'año': 2025,
#     'materia': 'Programación 3',
#     'comision': 'C5',
#     'estado': 'Pendiente',
#     'codigo': 'P3'}],
#   'telefono': '(381)598-7961',
#   'github': '@FabriMazza',
#   'foto': False},
#  '61905': {'legajo': '61905',
#   'nombre': 'Martinez, Augusto',
#   'cursos': [{'año': 2025,
#     'materia': 'Programación 3',
#     'comision': 'C5',
#     'estado': 'Pendiente',
#     'codigo': 'P3'}],
#   'telefono': '(381)580-1228',
#   'github': '@AugustoMartinez01',
#   'foto': False},
#  '61908': {'legajo': '61908',
#   'nombre': 'Costilla, Ignacio',
#   'cursos': [{'año': 2025,
#     'materia': 'Programación 3',
#     'comision': 'C5',
#     'estado': 'Pendiente',
#     'codigo': 'P3'}],
#   'telefono': '(381)207-4525',
#   'github': '@Ignacio-32',
#   'foto': False},
#  '61912': {'legajo': '61912',
#   'nombre': 'Nuñez, Arturo Valentin',
#   'cursos': [{'año': 2025,
#     'materia': 'Programación 3',
#     'comision': 'C5',
#     'estado': 'Pendiente',
#     'codigo': 'P3'}],
#   'telefono': '(381)367-1656',
#   'github': '',
#   'foto': False},
#  '61962': {'legajo': '61962',
#   'nombre': 'Robledo, Rocio Micaela',
#   'cursos': [{'año': 2025,
#     'materia': 'Programación 3',
#     'comision': 'C5',
#     'estado': 'Pendiente',
#     'codigo': 'P3'}],
#   'telefono': '(381)475-8990',
#   'github': '@micaroro',
#   'foto': False},
#  '62104': {'legajo': '62104',
#   'nombre': 'Robledo, Juan Gerardo',
#   'cursos': [{'año': 2025,
#     'materia': 'Programación 3',
#     'comision': 'C5',
#     'estado': 'Pendiente',
#     'codigo': 'P3'}],
#   'telefono': '(381)468-4269',
#   'github': '@Juanrobledo100',
#   'foto': False},
#  '61052': {'legajo': '61052',
#   'nombre': 'Reynoso, Braian Nicolás',
#   'cursos': [{'año': 2025,
#     'materia': 'Programación 3',
#     'comision': 'C5',
#     'estado': 'Regular',
#     'codigo': 'P3'}],
#   'telefono': '(381)654-0412',
#   'github': '@Braian-Reynoso',
#   'foto': False},
#  '61252': {'legajo': '61252',
#   'nombre': 'Aguirre Rojas, Lourdes Valenti',
#   'cursos': [{'año': 2025,
#     'materia': 'Programación 3',
#     'comision': 'C5',
#     'estado': 'Regular',
#     'codigo': 'P3'}],
#   'telefono': '(381)500-1078',
#   'github': '@lourdesaguirre97',
#   'foto': False},
#  '61914': {'legajo': '61914',
#   'nombre': 'Robles, Leandro Gonzalo',
#   'cursos': [{'año': 2025,
#     'materia': 'Programación 3',
#     'comision': 'C5',
#     'estado': 'Regular',
#     'codigo': 'P3'}],
#   'telefono': '(381)611-5577',
#   'github': '@GonzaloRobles209',
#   'foto': False},
#  '61061': {'legajo': '61061',
#   'nombre': 'Velardez, Leandro Ivan',
#   'cursos': [{'año': 2025,
#     'materia': 'Programación 3',
#     'comision': 'C5',
#     'estado': 'Libre',
#     'codigo': 'P3'}],
#   'telefono': '(381)397-5576',
#   'github': '@ivito01',
#   'foto': False},
#  '61322': {'legajo': '61322',
#   'nombre': 'Juarez, Thiago',
#   'cursos': [{'año': 2025,
#     'materia': 'Programación 3',
#     'comision': 'C5',
#     'estado': 'Libre',
#     'codigo': 'P3'}],
#   'telefono': '(381)418-2169',
#   'github': '',
#   'foto': False},
#  '61437': {'legajo': '61437',
#   'nombre': 'Holmquist, Ignacio Tobias',
#   'cursos': [{'año': 2025,
#     'materia': 'Programación 3',
#     'comision': 'C5',
#     'estado': 'Libre',
#     'codigo': 'P3'}],
#   'telefono': '(381)516-9171',
#   'github': '',
#   'foto': False},
#  '61566': {'legajo': '61566',
#   'nombre': 'Medina Costilla, Abigail',
#   'cursos': [{'año': 2025,
#     'materia': 'Programación 3',
#     'comision': 'C5',
#     'estado': 'Libre',
#     'codigo': 'P3'}],
#   'telefono': '(381)655-7818',
#   'github': '',
#   'foto': False},
#  '61858': {'legajo': '61858',
#   'nombre': 'Perez, Facundo Agustin',
#   'cursos': [{'año': 2025,
#     'materia': 'Programación 3',
#     'comision': 'C5',
#     'estado': 'Libre',
#     'codigo': 'P3'}],
#   'telefono': '(381)661-8312',
#   'github': '',
#   'foto': False},
#  '62612': {'legajo': '62612',
#   'nombre': 'Campos, Julieta Antonella',
#   'cursos': [{'año': 2025,
#     'materia': 'Programación 3',
#     'comision': 'C5',
#     'estado': 'Libre',
#     'codigo': 'P3'}],
#   'telefono': '(381)605-0864',
#   'github': '@julicamposs',
#   'foto': False},
#  '61131': {'legajo': '61131',
#   'nombre': 'Agostino Colombres, Juan Manuel',
#   'cursos': [{'año': 2025,
#     'materia': 'Programación 4',
#     'comision': 'C1',
#     'estado': 'Promocionado',
#     'codigo': 'P4'}],
#   'telefono': '(381)684-8399',
#   'github': '@JuanmaAgostino',
#   'foto': True},
#  '61565': {'legajo': '61565',
#   'nombre': 'Carrizo, Mauro',
#   'cursos': [{'año': 2025,
#     'materia': 'Programación 4',
#     'comision': 'C1',
#     'estado': 'Promocionado',
#     'codigo': 'P4'}],
#   'telefono': '(381)610-8745',
#   'github': '@DarkoDarkShadow',
#   'foto': True},
#  '61236': {'legajo': '61236',
#   'nombre': 'Drachenberg, Franco Eduardo',
#   'cursos': [{'año': 2025,
#     'materia': 'Programación 4',
#     'comision': 'C1',
#     'estado': 'Promocionado',
#     'codigo': 'P4'}],
#   'telefono': '(381)670-8708',
#   'github': '@FDrach',
#   'foto': True},
#  '61198': {'legajo': '61198',
#   'nombre': 'Ferreyra Appas, Santiago Nicolás',
#   'cursos': [{'año': 2025,
#     'materia': 'Programación 4',
#     'comision': 'C1',
#     'estado': 'Promocionado',
#     'codigo': 'P4'}],
#   'telefono': '(381)648-4455',
#   'github': '@Ercutt',
#   'foto': True},
#  '61167': {'legajo': '61167',
#   'nombre': 'Giacobbe, Franco',
#   'cursos': [{'año': 2025,
#     'materia': 'Programación 4',
#     'comision': 'C1',
#     'estado': 'Promocionado',
#     'codigo': 'P4'}],
#   'telefono': '(381)588-0371',
#   'github': '@frandg47',
#   'foto': True},
#  '61073': {'legajo': '61073',
#   'nombre': 'González Chavez, Rodrigo',
#   'cursos': [{'año': 2025,
#     'materia': 'Programación 4',
#     'comision': 'C1',
#     'estado': 'Promocionado',
#     'codigo': 'P4'}],
#   'telefono': '(381)624-3000',
#   'github': '@rodrigogc21',
#   'foto': True},
#  '61120': {'legajo': '61120',
#   'nombre': 'Guerrero, Ana Sofía',
#   'cursos': [{'año': 2025,
#     'materia': 'Programación 4',
#     'comision': 'C1',
#     'estado': 'Promocionado',
#     'codigo': 'P4'}],
#   'telefono': '(381)418-1564',
#   'github': '@AnaSofi03',
#   'foto': False},
#  '54911': {'legajo': '54911',
#   'nombre': 'Jatib, Rodrigo Gabriel',
#   'cursos': [{'año': 2025,
#     'materia': 'Programación 4',
#     'comision': 'C1',
#     'estado': 'Promocionado',
#     'codigo': 'P4'}],
#   'telefono': '(381)655-3096',
#   'github': '@RodrigoJatib',
#   'foto': True},
#  '61035': {'legajo': '61035',
#   'nombre': 'Ledesma, Paulo Marcelo',
#   'cursos': [{'año': 2025,
#     'materia': 'Programación 4',
#     'comision': 'C1',
#     'estado': 'Promocionado',
#     'codigo': 'P4'}],
#   'telefono': '(381)664-8356',
#   'github': '@pauloled',
#   'foto': True},
#  '61115': {'legajo': '61115',
#   'nombre': 'Ledesma, Santiago Esteban',
#   'cursos': [{'año': 2025,
#     'materia': 'Programación 4',
#     'comision': 'C1',
#     'estado': 'Promocionado',
#     'codigo': 'P4'}],
#   'telefono': '(381)346-3696',
#   'github': '@santled',
#   'foto': True},
#  '61335': {'legajo': '61335',
#   'nombre': 'León, Lucas Ismael',
#   'cursos': [{'año': 2025,
#     'materia': 'Programación 4',
#     'comision': 'C1',
#     'estado': 'Promocionado',
#     'codigo': 'P4'}],
#   'telefono': '(381)609-7898',
#   'github': '@LuquitasLeon',
#   'foto': True},
#  '61911': {'legajo': '61911',
#   'nombre': 'Llanos, Luciano',
#   'cursos': [{'año': 2025,
#     'materia': 'Programación 4',
#     'comision': 'C1',
#     'estado': 'Promocionado',
#     'codigo': 'P4'}],
#   'telefono': '(381)325-9224',
#   'github': '@LucianoLlanos',
#   'foto': True},
#  '61993': {'legajo': '61993',
#   'nombre': 'Medina, Juan Ignacio',
#   'cursos': [{'año': 2025,
#     'materia': 'Programación 4',
#     'comision': 'C1',
#     'estado': 'Promocionado',
#     'codigo': 'P4'}],
#   'telefono': '(381)517-1937',
#   'github': '@Soulmain1',
#   'foto': True},
#  '61338': {'legajo': '61338',
#   'nombre': 'Morales, Juan Daniel',
#   'cursos': [{'año': 2025,
#     'materia': 'Programación 4',
#     'comision': 'C1',
#     'estado': 'Promocionado',
#     'codigo': 'P4'}],
#   'telefono': '(381)665-5296',
#   'github': '@JuanMo17',
#   'foto': True},
#  '61046': {'legajo': '61046',
#   'nombre': 'Ponce, Luz Micaela',
#   'cursos': [{'año': 2025,
#     'materia': 'Programación 4',
#     'comision': 'C1',
#     'estado': 'Promocionado',
#     'codigo': 'P4'}],
#   'telefono': '(381)664-7165',
#   'github': '@Mica8p',
#   'foto': True},
#  '61033': {'legajo': '61033',
#   'nombre': 'Quiroga, José María',
#   'cursos': [{'año': 2025,
#     'materia': 'Programación 4',
#     'comision': 'C1',
#     'estado': 'Promocionado',
#     'codigo': 'P4'}],
#   'telefono': '(11)2399-7675',
#   'github': '@jose-qui',
#   'foto': True},
#  '62175': {'legajo': '62175',
#   'nombre': 'Quiroga, Marcela Noemí',
#   'cursos': [{'año': 2025,
#     'materia': 'Programación 4',
#     'comision': 'C1',
#     'estado': 'Promocionado',
#     'codigo': 'P4'}],
#   'telefono': '(381)593-8430',
#   'github': '@Marce-Quiroga',
#   'foto': True},
#  '61084': {'legajo': '61084',
#   'nombre': 'Ramírez, Leonardo',
#   'cursos': [{'año': 2025,
#     'materia': 'Programación 4',
#     'comision': 'C1',
#     'estado': 'Promocionado',
#     'codigo': 'P4'}],
#   'telefono': '(381)348-9132',
#   'github': '@Leoramirez777',
#   'foto': True},
#  '61315': {'legajo': '61315',
#   'nombre': 'Robles, Thiago',
#   'cursos': [{'año': 2025,
#     'materia': 'Programación 4',
#     'comision': 'C1',
#     'estado': 'Promocionado',
#     'codigo': 'P4'}],
#   'telefono': '(381)344-7120',
#   'github': '@T1T0Dev',
#   'foto': True},
#  '61468': {'legajo': '61468',
#   'nombre': 'Samaniego, Esteban Maximiliano',
#   'cursos': [{'año': 2025,
#     'materia': 'Programación 4',
#     'comision': 'C1',
#     'estado': 'Promocionado',
#     'codigo': 'P4'}],
#   'telefono': '(381)679-6586',
#   'github': '@MaxiSama12',
#   'foto': True},
#  '61240': {'legajo': '61240',
#   'nombre': 'Timo, Héctor Gabriel',
#   'cursos': [{'año': 2025,
#     'materia': 'Programación 4',
#     'comision': 'C1',
#     'estado': 'Promocionado',
#     'codigo': 'P4'}],
#   'telefono': '(381)343-0992',
#   'github': '@GabrielTimo006',
#   'foto': True},
#  '61725': {'legajo': '61725',
#   'nombre': 'Villagra, Jorge Sebastián',
#   'cursos': [{'año': 2025,
#     'materia': 'Programación 4',
#     'comision': 'C1',
#     'estado': 'Promocionado',
#     'codigo': 'P4'}],
#   'telefono': '(381)594-1635',
#   'github': '@JorgeVillagraa',
#   'foto': True},
#  '61551': {'legajo': '61551',
#   'nombre': 'Díaz Valdez, Ignacio',
#   'cursos': [{'año': 2025,
#     'materia': 'Programación 4',
#     'comision': 'C1',
#     'estado': 'Regular',
#     'codigo': 'P4'}],
#   'telefono': '(381)695-8566',
#   'github': '@IgnacioDiazV',
#   'foto': True},
#  '61472': {'legajo': '61472',
#   'nombre': 'Díaz, Julieta Camila',
#   'cursos': [{'año': 2025,
#     'materia': 'Programación 4',
#     'comision': 'C1',
#     'estado': 'Regular',
#     'codigo': 'P4'}],
#   'telefono': '(381)652-9981',
#   'github': '@juliidiiaz04',
#   'foto': False},
#  '62318': {'legajo': '62318',
#   'nombre': 'Quiroga Castro, Lisandro',
#   'cursos': [{'año': 2025,
#     'materia': 'Programación 4',
#     'comision': 'C1',
#     'estado': 'Regular',
#     'codigo': 'P4'}],
#   'telefono': '(381)390-9133',
#   'github': '@Lisandro-18',
#   'foto': True},
#  '61337': {'legajo': '61337',
#   'nombre': 'Díaz, Christian Gabriel',
#   'cursos': [{'año': 2025,
#     'materia': 'Programación 4',
#     'comision': 'C1',
#     'estado': 'Libre',
#     'codigo': 'P4'}],
#   'telefono': '(381)571-4797',
#   'github': '',
#   'foto': False},
#  '61805': {'legajo': '61805',
#   'nombre': 'Jerez, Tomás',
#   'cursos': [{'año': 2025,
#     'materia': 'Programación 4',
#     'comision': 'C1',
#     'estado': 'Libre',
#     'codigo': 'P4'}],
#   'telefono': '(381)338-0186',
#   'github': '@ElTommmy',
#   'foto': False},
#  '61719': {'legajo': '61719',
#   'nombre': 'Amoedo, Pablo Isaías',
#   'cursos': [{'año': 2025,
#     'materia': 'Programación 4',
#     'comision': 'C3',
#     'estado': 'Promocionado',
#     'codigo': 'P4'}],
#   'telefono': '(381)463-6126',
#   'github': '@Kryfter',
#   'foto': True},
#  '61150': {'legajo': '61150',
#   'nombre': 'Molina Navarro, Juan Martín',
#   'cursos': [{'año': 2025,
#     'materia': 'Programación 4',
#     'comision': 'C3',
#     'estado': 'Promocionado',
#     'codigo': 'P4'}],
#   'telefono': '(381)644-3413',
#   'github': '@JuanMolinaNavarro',
#   'foto': True}}
